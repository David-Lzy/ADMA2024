# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST4

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try5_c_Classfier

# %%
DEVICE = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=1)

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 0:
        continue
    trainer = Trainer(
        dataset=i_dataset,
        epoch=1000,
        model=model_class,
        device=DEVICE,
    )
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00311: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00444: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00532: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00636: reducing learning rate of group 0 to 1.0000e-04.
# 1 Adiac
# {'accuracy': 0.7076923076923077,
#  'duration': 799.7332932949066,
#  'f1': 0.5537802849778619,
#  'loss': 2.9572841099330356,
#  'precision': 0.5044259638200888,
#  'recall': 0.6391986391986393}
# Epoch 00160: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00541: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00651: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00702: reducing learning rate of group 0 to 1.0000e-04.
# 3 AllGestureWiimoteY
# {'accuracy': 1.0,
#  'duration': 277.436425447464,
#  'f1': 1.0,
#  'loss': 1.4611948728561401,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00089: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00140: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00191: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00242: reducing learning rate of group 0 to 1.0000e-04.
# 5 ArrowHead
# {'accuracy': 1.0,
#  'duration': 46.1314263343811,
#  'f1': 1.0,
#  'loss': 0.551514208316803,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00118: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00169: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00271: reducing learning rate of group 0 to 1.0000e-04.
# 7 Beef
# {'accuracy': 1.0,
#  'duration': 30.69257879257202,
#  'f1': 1.0,
#  'loss': 0.9050595164299011,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00118: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00169: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.0000e-04.
# 9 BirdChicken
# {'accuracy': 1.0,
#  'duration': 29.533456802368164,
#  'f1': 1.0,
#  'loss': 0.3133109211921692,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00141: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00892: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00943: reducing learning rate of group 0 to 1.2500e-04.
# 11 Car
# {'accuracy': 1.0,
#  'duration': 50.930681228637695,
#  'f1': 1.0,
#  'loss': 0.7437180876731873,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00356: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00453: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00504: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00724: reducing learning rate of group 0 to 1.0000e-04.
# 13 ChlorineConcentration
# {'accuracy': 0.9957173447537473,
#  'duration': 1316.2691984176636,
#  'f1': 0.9942336469208716,
#  'loss': 0.5553840547800064,
#  'precision': 0.9950695692140559,
#  'recall': 0.9934130197288091}
# Epoch 00406: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00470: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00521: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00572: reducing learning rate of group 0 to 1.0000e-04.
# 15 Coffee
# {'accuracy': 1.0,
#  'duration': 36.12536907196045,
#  'f1': 1.0,
#  'loss': 0.31327301263809204,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00232: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00283: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00391: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00442: reducing learning rate of group 0 to 1.0000e-04.
# 17 CricketX
# {'accuracy': 1.0,
#  'duration': 208.40400743484497,
#  'f1': 1.0,
#  'loss': 1.619011572429112,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00255: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00306: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00357: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00408: reducing learning rate of group 0 to 1.0000e-04.
# 19 CricketZ
# {'accuracy': 0.9974358974358974,
#  'duration': 208.57214784622192,
#  'f1': 0.9976847385683967,
#  'loss': 1.621024830000741,
#  'precision': 0.9977477477477478,
#  'recall': 0.9976851851851851}
# 21 DiatomSizeReduction
# {'accuracy': 1.0,
#  'duration': 66.3418390750885,
#  'f1': 1.0,
#  'loss': 0.7436894774436951,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00080: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00131: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00182: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00233: reducing learning rate of group 0 to 1.0000e-04.
# 23 DistalPhalanxOutlineCorrect
# {'accuracy': 0.9916666666666667,
#  'duration': 415.1166865825653,
#  'f1': 0.9910707641937644,
#  'loss': 0.3210830628871918,
#  'precision': 0.9906210227069976,
#  'recall': 0.9915272415272416}
# Epoch 00074: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00125: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00176: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00227: reducing learning rate of group 0 to 1.0000e-04.
# 25 DodgerLoopDay
# {'accuracy': 1.0,
#  'duration': 59.140058279037476,
#  'f1': 1.0,
#  'loss': 1.16948801279068,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00058: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00109: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00160: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00211: reducing learning rate of group 0 to 1.0000e-04.
# 27 DodgerLoopWeekend
# {'accuracy': 1.0,
#  'duration': 47.00973105430603,
#  'f1': 1.0,
#  'loss': 0.3133096396923065,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00106: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00157: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00259: reducing learning rate of group 0 to 1.0000e-04.
# 29 ECG5000
# {'accuracy': 0.988,
#  'duration': 1506.8926131725311,
#  'f1': 0.9613539270456786,
#  'loss': 0.9165547788143158,
#  'precision': 0.9811418047882137,
#  'recall': 0.9462384775498067}
# Epoch 00222: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00273: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00324: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.0000e-04.
# 31 EOGHorizontalSignal
# {'accuracy': 1.0,
#  'duration': 542.4848942756653,
#  'f1': 1.0,
#  'loss': 1.6196853319803874,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00103: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00154: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00256: reducing learning rate of group 0 to 1.0000e-04.
# 33 Earthquakes
# {'accuracy': 0.9937888198757764,
#  'duration': 209.09749627113342,
#  'f1': 0.9893412777226084,
#  'loss': 0.32769887149333954,
#  'precision': 0.9962406015037594,
#  'recall': 0.9827586206896552}
# Epoch 00378: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00429: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00480: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00531: reducing learning rate of group 0 to 1.0000e-04.
# 35 EthanolLevel
# {'accuracy': 1.0,
#  'duration': 1031.04230594635,
#  'f1': 1.0,
#  'loss': 0.7444028332829475,
#  'precision': 1.0,
#  'recall': 1.0}
# 37 FaceFour
# {'accuracy': 1.0,
#  'duration': 40.651252031326294,
#  'f1': 1.0,
#  'loss': 0.7436804175376892,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00069: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00697: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00813: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00864: reducing learning rate of group 0 to 1.0000e-04.
# 39 FiftyWords
# {'accuracy': 0.6622222222222223,
#  'duration': 237.3427631855011,
#  'f1': 0.2917402931367947,
#  'loss': 3.2593269050121307,
#  'precision': 0.265797999431113,
#  'recall': 0.3633333333333333}
# Epoch 00123: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00174: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00276: reducing learning rate of group 0 to 1.0000e-04.
# 41 FordA
# {'accuracy': 0.9980560955290197,
#  'duration': 2028.3367216587067,
#  'f1': 0.9980548805044425,
#  'loss': 0.3153808017571767,
#  'precision': 0.9980480397059096,
#  'recall': 0.9980618755266643}
# Epoch 00082: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00133: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00184: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00235: reducing learning rate of group 0 to 1.0000e-04.
# 43 FreezerRegularTrain
# {'accuracy': 1.0,
#  'duration': 445.22597098350525,
#  'f1': 1.0,
#  'loss': 0.3133387267589569,
#  'precision': 1.0,
#  'recall': 1.0}
# 45 Fungi
# {'accuracy': 1.0,
#  'duration': 49.65372920036316,
#  'f1': 1.0,
#  'loss': 1.98159658908844,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00223: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00274: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00325: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00376: reducing learning rate of group 0 to 1.0000e-04.
# 47 GestureMidAirD2
# {'accuracy': 0.9807692307692307,
#  'duration': 119.79119873046875,
#  'f1': 0.9805788982259571,
#  'loss': 2.3515065908432007,
#  'precision': 0.9837606837606838,
#  'recall': 0.9807692307692307}
# Epoch 00248: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00299: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00478: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00529: reducing learning rate of group 0 to 1.0000e-04.
# 49 GesturePebbleZ1
# {'accuracy': 1.0,
#  'duration': 111.44121599197388,
#  'f1': 1.0,
#  'loss': 1.045447587966919,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00146: reducing learning rate of group 0 to 5.0000e-04.
# 51 GunPoint
# {'accuracy': 1.0,
#  'duration': 137.94550824165344,
#  'f1': 1.0,
#  'loss': 0.3132743239402771,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00132: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00233: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00340: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00391: reducing learning rate of group 0 to 1.0000e-04.
# 53 GunPointMaleVersusFemale
# {'accuracy': 1.0,
#  'duration': 310.82362961769104,
#  'f1': 1.0,
#  'loss': 0.316288818915685,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00055: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00106: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00157: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.0000e-04.
# 55 Ham
# {'accuracy': 1.0,
#  'duration': 73.34732985496521,
#  'f1': 1.0,
#  'loss': 0.3132932186126709,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00134: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00185: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00448: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00499: reducing learning rate of group 0 to 1.0000e-04.
# 57 Haptics
# {'accuracy': 1.0,
#  'duration': 262.3153922557831,
#  'f1': 1.0,
#  'loss': 0.9065340360005697,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00065: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00116: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00167: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00218: reducing learning rate of group 0 to 1.0000e-04.
# 59 HouseTwenty
# {'accuracy': 1.0,
#  'duration': 144.96542286872864,
#  'f1': 1.0,
#  'loss': 0.3133271336555481,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00104: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00155: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00206: reducing learning rate of group 0 to 1.0000e-04.
# 61 InsectEPGRegularTrain
# {'accuracy': 1.0,
#  'duration': 92.33058595657349,
#  'f1': 1.0,
#  'loss': 0.551535964012146,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00132: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00215: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00304: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00355: reducing learning rate of group 0 to 1.0000e-04.
# 63 InsectWingbeatSound
# {'accuracy': 0.9818181818181818,
#  'duration': 355.68552136421204,
#  'f1': 0.9816931036443232,
#  'loss': 1.5586561560630798,
#  'precision': 0.9822282980177716,
#  'recall': 0.9818181818181817}
# Epoch 00145: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00196: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00280: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00331: reducing learning rate of group 0 to 1.0000e-04.
# 65 LargeKitchenAppliances
# {'accuracy': 1.0,
#  'duration': 339.49775409698486,
#  'f1': 1.0,
#  'loss': 0.5515094796816508,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00252: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00303: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00354: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00452: reducing learning rate of group 0 to 1.0000e-04.
# 67 Lightning7
# {'accuracy': 1.0,
#  'duration': 65.9556565284729,
#  'f1': 1.0,
#  'loss': 1.1659881472587585,
#  'precision': 1.0,
#  'recall': 1.0}
# 69 Meat
# {'accuracy': 1.0,
#  'duration': 41.83954095840454,
#  'f1': 1.0,
#  'loss': 0.5514745116233826,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00062: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00113: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00192: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00243: reducing learning rate of group 0 to 1.0000e-04.
# 71 MelbournePedestrian
# {'accuracy': 1.0,
#  'duration': 752.544175863266,
#  'f1': 1.0,
#  'loss': 1.4611651834688688,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00083: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00134: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00185: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00236: reducing learning rate of group 0 to 1.0000e-04.
# 73 MiddlePhalanxOutlineCorrect
# {'accuracy': 0.9933333333333333,
#  'duration': 436.25952553749084,
#  'f1': 0.9926899694197053,
#  'loss': 0.31952694058418274,
#  'precision': 0.9937728937728938,
#  'recall': 0.9916358685080724}
# Epoch 00063: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00165: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00216: reducing learning rate of group 0 to 1.0000e-04.
# 75 MixedShapesRegularTrain
# {'accuracy': 1.0,
#  'duration': 1213.2125442028046,
#  'f1': 1.0,
#  'loss': 0.9049302861094475,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00480: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00545: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00596: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00647: reducing learning rate of group 0 to 1.0000e-04.
# 77 MoteStrain
# {'accuracy': 1.0,
#  'duration': 205.67023038864136,
#  'f1': 1.0,
#  'loss': 0.31327348947525024,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00357: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00483: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00689: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00740: reducing learning rate of group 0 to 1.0000e-04.
# 79 NonInvasiveFetalECGThorax2
# {'accuracy': 0.9138888888888889,
#  'duration': 1760.7627832889557,
#  'f1': 0.867893411899948,
#  'loss': 2.86115576480997,
#  'precision': 0.8410800770099879,
#  'recall': 0.9037037037037037}
# Epoch 00211: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00262: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00313: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00364: reducing learning rate of group 0 to 1.0000e-04.
# 81 OliveOil
# {'accuracy': 0.9666666666666667,
#  'duration': 36.245753049850464,
#  'f1': 0.9575163398692811,
#  'loss': 0.7955801486968994,
#  'precision': 0.9722222222222222,
#  'recall': 0.95}
# Epoch 00174: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00225: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00276: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00327: reducing learning rate of group 0 to 1.0000e-04.
# 83 PhalangesOutlinesCorrect
# {'accuracy': 0.985,
#  'duration': 1304.8977854251862,
#  'f1': 0.9834366610762557,
#  'loss': 0.32806354863890286,
#  'precision': 0.9851095495589155,
#  'recall': 0.9818291993652313}
# Epoch 00252: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00303: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00354: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00405: reducing learning rate of group 0 to 1.0000e-04.
# 85 PickupGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 37.3446843624115,
#  'f1': 1.0,
#  'loss': 1.46142578125,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00368: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00707: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00758: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00860: reducing learning rate of group 0 to 1.0000e-04.
# 87 PigArtPressure
# {'accuracy': 0.9807692307692307,
#  'duration': 306.9241397380829,
#  'f1': 0.973076923076923,
#  'loss': 3.004048466682434,
#  'precision': 0.9679487179487178,
#  'recall': 0.9807692307692307}
# Epoch 00348: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00399: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00450: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00501: reducing learning rate of group 0 to 1.0000e-04.
# 89 Plane
# {'accuracy': 1.0,
#  'duration': 243.11633396148682,
#  'f1': 1.0,
#  'loss': 1.1654585599899292,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00277: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00328: reducing learning rate of group 0 to 1.0000e-04.
# 91 ProximalPhalanxOutlineAgeGroup
# {'accuracy': 0.9375,
#  'duration': 311.5190987586975,
#  'f1': 0.9412479630265475,
#  'loss': 0.6131025041852679,
#  'precision': 0.9387219657408107,
#  'recall': 0.9444666489030998}
# Epoch 00081: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00132: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00183: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00234: reducing learning rate of group 0 to 1.0000e-04.
# 93 ProximalPhalanxTW
# {'accuracy': 0.9025,
#  'duration': 312.06056118011475,
#  'f1': 0.6226081859580482,
#  'loss': 1.1466245651245117,
#  'precision': 0.6000820767375477,
#  'recall': 0.6547209480122325}
# 95 Rock
# {'accuracy': 1.0,
#  'duration': 95.78114676475525,
#  'f1': 1.0,
#  'loss': 0.7437055706977844,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00076: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00127: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00178: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00229: reducing learning rate of group 0 to 1.0000e-04.
# 97 SemgHandGenderCh2
# {'accuracy': 1.0,
#  'duration': 670.972650051117,
#  'f1': 1.0,
#  'loss': 0.3134191632270813,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00155: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00245: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00325: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00376: reducing learning rate of group 0 to 1.0000e-04.
# 99 SemgHandSubjectCh2
# {'accuracy': 0.9577777777777777,
#  'duration': 823.7974331378937,
#  'f1': 0.9576287488963275,
#  'loss': 0.9832453355193138,
#  'precision': 0.9593909347883768,
#  'recall': 0.9577777777777777}
# Epoch 00055: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00106: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00157: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.0000e-04.
# 101 ShapeletSim
# {'accuracy': 1.0,
#  'duration': 60.79658627510071,
#  'f1': 1.0,
#  'loss': 0.31329435110092163,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00075: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00126: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00177: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00228: reducing learning rate of group 0 to 1.0000e-04.
# 103 SmallKitchenAppliances
# {'accuracy': 0.9733333333333334,
#  'duration': 340.21837520599365,
#  'f1': 0.9733278706015408,
#  'loss': 0.5783158242702484,
#  'precision': 0.9736531488243961,
#  'recall': 0.9733333333333333}
# Epoch 00056: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00107: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00158: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.0000e-04.
# 105 SonyAIBORobotSurface1
# {'accuracy': 1.0,
#  'duration': 121.31311798095703,
#  'f1': 1.0,
#  'loss': 0.31330257654190063,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00164: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00216: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00267: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00318: reducing learning rate of group 0 to 1.0000e-04.
# 107 StarLightCurves
# {'accuracy': 0.993,
#  'duration': 3493.2150342464447,
#  'f1': 0.990119952536836,
#  'loss': 0.5588891543447971,
#  'precision': 0.9959770114942529,
#  'recall': 0.9846491228070176}
# Epoch 00185: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00236: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00347: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00491: reducing learning rate of group 0 to 1.0000e-04.
# 109 SwedishLeaf
# {'accuracy': 1.0,
#  'duration': 1067.0467483997345,
#  'f1': 1.0,
#  'loss': 1.8165116608142853,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00156: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00207: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00258: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00309: reducing learning rate of group 0 to 1.0000e-04.
# 111 SyntheticControl
# {'accuracy': 1.0,
#  'duration': 254.7851595878601,
#  'f1': 1.0,
#  'loss': 1.0436071157455444,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00068: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00119: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00170: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00221: reducing learning rate of group 0 to 1.0000e-04.
# 113 ToeSegmentation2
# {'accuracy': 1.0,
#  'duration': 58.99986982345581,
#  'f1': 1.0,
#  'loss': 0.3133038878440857,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00449: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00500: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00556: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00607: reducing learning rate of group 0 to 1.0000e-04.
# 115 TwoLeadECG
# {'accuracy': 1.0,
#  'duration': 203.3812165260315,
#  'f1': 1.0,
#  'loss': 0.31327173113822937,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00075: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00126: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00177: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00228: reducing learning rate of group 0 to 1.0000e-04.
# 117 UMD
# {'accuracy': 1.0,
#  'duration': 122.42854809761047,
#  'f1': 1.0,
#  'loss': 0.5515457987785339,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00121: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00211: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00290: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00370: reducing learning rate of group 0 to 1.0000e-04.
# 119 UWaveGestureLibraryX
# {'accuracy': 0.9933035714285714,
#  'duration': 884.5416507720947,
#  'f1': 0.9934698633345678,
#  'loss': 1.2806428500584193,
#  'precision': 0.993390736777271,
#  'recall': 0.9936586282058724}
# Epoch 00197: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00313: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00364: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00415: reducing learning rate of group 0 to 1.0000e-04.
# 121 UWaveGestureLibraryZ
# {'accuracy': 0.9966517857142857,
#  'duration': 885.8844809532166,
#  'f1': 0.9966640609933981,
#  'loss': 1.2773872784205846,
#  'precision': 0.9966869889018691,
#  'recall': 0.9966598009166832}
# Epoch 00116: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00167: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00218: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00269: reducing learning rate of group 0 to 1.0000e-04.
# 123 Wine
# {'accuracy': 1.0,
#  'duration': 39.56537914276123,
#  'f1': 1.0,
#  'loss': 0.3154360055923462,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00140: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00191: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00242: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00293: reducing learning rate of group 0 to 1.0000e-04.
# 125 Worms
# {'accuracy': 0.994475138121547,
#  'duration': 179.38528537750244,
#  'f1': 0.9902040816326532,
#  'loss': 0.9102492729822794,
#  'precision': 0.9888888888888889,
#  'recall': 0.992}
# Epoch 00160: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00211: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00320: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00371: reducing learning rate of group 0 to 1.0000e-04.
# 127 Yoga
# {'accuracy': 1.0,
#  'duration': 622.0272645950317,
#  'f1': 1.0,
#  'loss': 0.3132729887962341,
#  'precision': 1.0,
#  'recall': 1.0}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
