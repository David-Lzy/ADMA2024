# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST4

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try5_c_Classfier

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 1:
        continue
    trainer = Trainer(dataset=i_dataset, epoch=1000, model=model_class)
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00220: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00271: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00322: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00373: reducing learning rate of group 0 to 1.0000e-04.
# 0 ACSF1
# {'accuracy': 0.98,
#  'duration': 173.46393060684204,
#  'f1': 0.9799498746867169,
#  'loss': 1.4807507991790771,
#  'precision': 0.9818181818181818,
#  'recall': 0.9800000000000001}
# Epoch 00148: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00278: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00400: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00451: reducing learning rate of group 0 to 1.0000e-04.
# 2 AllGestureWiimoteX
# {'accuracy': 1.0,
#  'duration': 277.2332332134247,
#  'f1': 1.0,
#  'loss': 1.4612454175949097,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00179: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00487: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00883: reducing learning rate of group 0 to 1.2500e-04.
# 4 AllGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 277.02532863616943,
#  'f1': 1.0,
#  'loss': 1.461214828491211,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00262: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00313: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00364: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00415: reducing learning rate of group 0 to 1.0000e-04.
# 6 BME
# {'accuracy': 1.0,
#  'duration': 104.09774231910706,
#  'f1': 1.0,
#  'loss': 0.5515004992485046,
#  'precision': 1.0,
#  'recall': 1.0}
# 8 BeetleFly
# {'accuracy': 1.0,
#  'duration': 30.95568561553955,
#  'f1': 1.0,
#  'loss': 0.31326812505722046,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00577: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00636: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00687: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00738: reducing learning rate of group 0 to 1.0000e-04.
# 10 CBF
# {'accuracy': 1.0,
#  'duration': 191.76079988479614,
#  'f1': 1.0,
#  'loss': 0.5514584183692932,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00055: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00106: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00157: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.0000e-04.
# 12 Chinatown
# {'accuracy': 1.0,
#  'duration': 68.4699764251709,
#  'f1': 1.0,
#  'loss': 0.31331074237823486,
#  'precision': 1.0,
#  'recall': 1.0}
# 14 CinCECGTorso
# {'accuracy': 1.0,
#  'duration': 742.6617784500122,
#  'f1': 1.0,
#  'loss': 0.7436864972114563,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00105: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00156: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00207: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00258: reducing learning rate of group 0 to 1.0000e-04.
# 16 Computers
# {'accuracy': 1.0,
#  'duration': 225.7259271144867,
#  'f1': 1.0,
#  'loss': 0.3133334144949913,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00197: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00278: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00336: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00387: reducing learning rate of group 0 to 1.0000e-04.
# 18 CricketY
# {'accuracy': 1.0,
#  'duration': 199.28866863250732,
#  'f1': 1.0,
#  'loss': 1.6357509749276298,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00121: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00172: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00223: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00289: reducing learning rate of group 0 to 1.0000e-04.
# 20 Crop
# {'accuracy': 0.9655555555555555,
#  'duration': 6521.938114404678,
#  'f1': 0.965420104265304,
#  'loss': 2.2816835968895295,
#  'precision': 0.9662004371826746,
#  'recall': 0.9655555555555556}
# Epoch 00075: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00126: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00177: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00294: reducing learning rate of group 0 to 1.0000e-04.
# 22 DistalPhalanxOutlineAgeGroup
# {'accuracy': 0.9825,
#  'duration': 290.2806644439697,
#  'f1': 0.9849461053133273,
#  'loss': 0.5672853929655892,
#  'precision': 0.989279992460654,
#  'recall': 0.981003868094533}
# Epoch 00164: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00215: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00266: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00317: reducing learning rate of group 0 to 1.0000e-04.
# 24 DistalPhalanxTW
# {'accuracy': 0.9775,
#  'duration': 289.9276671409607,
#  'f1': 0.9434957766691882,
#  'loss': 1.0650718723024641,
#  'precision': 0.9801135507966627,
#  'recall': 0.9232804232804233}
# Epoch 00054: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00105: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00156: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00207: reducing learning rate of group 0 to 1.0000e-04.
# 26 DodgerLoopGame
# {'accuracy': 1.0,
#  'duration': 45.94351148605347,
#  'f1': 1.0,
#  'loss': 0.31330832839012146,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00114: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00165: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00216: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00267: reducing learning rate of group 0 to 1.0000e-04.
# 28 ECG200
# {'accuracy': 1.0,
#  'duration': 224.65593957901,
#  'f1': 1.0,
#  'loss': 0.3132784813642502,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00351: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00402: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00453: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00504: reducing learning rate of group 0 to 1.0000e-04.
# 30 ECGFiveDays
# {'accuracy': 1.0,
#  'duration': 131.91405701637268,
#  'f1': 1.0,
#  'loss': 0.3132915198802948,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00174: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00253: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00304: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00355: reducing learning rate of group 0 to 1.0000e-04.
# 32 EOGVerticalSignal
# {'accuracy': 1.0,
#  'duration': 539.5471863746643,
#  'f1': 1.0,
#  'loss': 1.6191314458847046,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00065: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00116: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00167: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00218: reducing learning rate of group 0 to 1.0000e-04.
# 34 ElectricDevices
# {'accuracy': 0.9790499663903204,
#  'duration': 17600.363397359848,
#  'f1': 0.9753209484269055,
#  'loss': 1.1863562345504761,
#  'precision': 0.9757105537781777,
#  'recall': 0.9752393443031105}
# Epoch 00288: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00427: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00478: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00529: reducing learning rate of group 0 to 1.0000e-04.
# 36 FaceAll
# {'accuracy': 1.0,
#  'duration': 1285.9839713573456,
#  'f1': 1.0,
#  'loss': 1.7548278305265639,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00282: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00395: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00446: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00497: reducing learning rate of group 0 to 1.0000e-04.
# 38 FacesUCR
# {'accuracy': 1.0,
#  'duration': 683.195723772049,
#  'f1': 1.0,
#  'loss': 1.7551149427890778,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00264: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00466: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00541: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00592: reducing learning rate of group 0 to 1.0000e-04.
# 40 Fish
# {'accuracy': 1.0,
#  'duration': 132.18331027030945,
#  'f1': 1.0,
#  'loss': 1.1654976606369019,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00148: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00199: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00250: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00301: reducing learning rate of group 0 to 1.0000e-04.
# 42 FordB
# {'accuracy': 0.9972497249724972,
#  'duration': 2502.076691389084,
#  'f1': 0.9972482563208369,
#  'loss': 0.3160032760678676,
#  'precision': 0.9972482563208369,
#  'recall': 0.9972482563208369}
# Epoch 00099: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00150: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00201: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00252: reducing learning rate of group 0 to 1.0000e-04.
# 44 FreezerSmallTrain
# {'accuracy': 1.0,
#  'duration': 397.4591326713562,
#  'f1': 1.0,
#  'loss': 0.3133264482021332,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00332: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00582: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00701: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00752: reducing learning rate of group 0 to 1.0000e-04.
# 46 GestureMidAirD1
# {'accuracy': 1.0,
#  'duration': 163.85143494606018,
#  'f1': 1.0,
#  'loss': 2.322541296482086,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00163: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00219: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00270: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00355: reducing learning rate of group 0 to 1.0000e-04.
# 48 GestureMidAirD3
# {'accuracy': 0.8942307692307693,
#  'duration': 163.29211521148682,
#  'f1': 0.862006771509034,
#  'loss': 2.4414998292922974,
#  'precision': 0.851037851037851,
#  'recall': 0.8942307692307693}
# Epoch 00219: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00270: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00321: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00372: reducing learning rate of group 0 to 1.0000e-04.
# 50 GesturePebbleZ2
# {'accuracy': 1.0,
#  'duration': 130.62877416610718,
#  'f1': 1.0,
#  'loss': 1.0445265372594197,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00172: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00223: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00274: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00325: reducing learning rate of group 0 to 1.0000e-04.
# 52 GunPointAgeSpan
# {'accuracy': 1.0,
#  'duration': 333.34654450416565,
#  'f1': 1.0,
#  'loss': 0.3141923248767853,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00091: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00142: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00193: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00244: reducing learning rate of group 0 to 1.0000e-04.
# 54 GunPointOldVersusYoung
# {'accuracy': 1.0,
#  'duration': 334.13584303855896,
#  'f1': 1.0,
#  'loss': 0.3133214513460795,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00189: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00292: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00343: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00394: reducing learning rate of group 0 to 1.0000e-04.
# 56 HandOutlines
# {'accuracy': 0.991,
#  'duration': 2559.772880792618,
#  'f1': 0.9902043481810019,
#  'loss': 0.32331457175314426,
#  'precision': 0.9930448222565688,
#  'recall': 0.9875690607734806}
# Epoch 00101: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00152: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00203: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00254: reducing learning rate of group 0 to 1.0000e-04.
# 58 Herring
# {'accuracy': 1.0,
#  'duration': 56.384910583496094,
#  'f1': 1.0,
#  'loss': 0.31343042850494385,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00493: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00544: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00595: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00646: reducing learning rate of group 0 to 1.0000e-04.
# 60 InlineSkate
# {'accuracy': 0.99,
#  'duration': 471.183474779129,
#  'f1': 0.9908479908479908,
#  'loss': 1.1788833141326904,
#  'precision': 0.9924812030075189,
#  'recall': 0.9897959183673469}
# Epoch 00056: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00107: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00158: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.0000e-04.
# 62 InsectEPGSmallTrain
# {'accuracy': 1.0,
#  'duration': 93.25913071632385,
#  'f1': 1.0,
#  'loss': 0.5515590310096741,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00144: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00200: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00251: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00417: reducing learning rate of group 0 to 1.0000e-04.
# 64 ItalyPowerDemand
# {'accuracy': 0.9701492537313433,
#  'duration': 219.016037940979,
#  'f1': 0.9700892857142858,
#  'loss': 0.3287430554628372,
#  'precision': 0.9722222222222222,
#  'recall': 0.9696969696969697}
# Epoch 00090: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00141: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00192: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00243: reducing learning rate of group 0 to 1.0000e-04.
# 66 Lightning2
# {'accuracy': 1.0,
#  'duration': 58.025639057159424,
#  'f1': 1.0,
#  'loss': 0.3133412003517151,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00346: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00397: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00448: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00499: reducing learning rate of group 0 to 1.0000e-04.
# 68 Mallat
# {'accuracy': 1.0,
#  'duration': 783.8834278583527,
#  'f1': 1.0,
#  'loss': 1.2742871046066284,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00308: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00359: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00410: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00461: reducing learning rate of group 0 to 1.0000e-04.
# 70 MedicalImages
# {'accuracy': 0.963254593175853,
#  'duration': 848.3333082199097,
#  'f1': 0.9628037070760543,
#  'loss': 1.4976161122322083,
#  'precision': 0.9869409439090685,
#  'recall': 0.9463733311915471}
# Epoch 00056: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00107: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00158: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00226: reducing learning rate of group 0 to 1.0000e-04.
# 72 MiddlePhalanxOutlineAgeGroup
# {'accuracy': 0.96,
#  'duration': 340.43204522132874,
#  'f1': 0.9537920558973191,
#  'loss': 0.5868999787739345,
#  'precision': 0.9634103641456583,
#  'recall': 0.9458260523661367}
# Epoch 00072: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00123: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00174: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.0000e-04.
# 74 MiddlePhalanxTW
# {'accuracy': 0.9323308270676691,
#  'duration': 340.9958562850952,
#  'f1': 0.8820395488209286,
#  'loss': 1.121846386364528,
#  'precision': 0.9451670363648584,
#  'recall': 0.8516648209671466}
# Epoch 00074: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00125: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00176: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00227: reducing learning rate of group 0 to 1.0000e-04.
# 76 MixedShapesSmallTrain
# {'accuracy': 1.0,
#  'duration': 855.1192288398743,
#  'f1': 1.0,
#  'loss': 0.9050277173519135,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00227: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00462: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00772: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00850: reducing learning rate of group 0 to 1.0000e-04.
# 78 NonInvasiveFetalECGThorax1
# {'accuracy': 0.9577777777777777,
#  'duration': 1794.1318907737732,
#  'f1': 0.9349519414262917,
#  'loss': 2.8228423513215164,
#  'precision': 0.9214180860297917,
#  'recall': 0.9523809523809523}
# Epoch 00180: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00274: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00325: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00515: reducing learning rate of group 0 to 1.0000e-04.
# 80 OSULeaf
# {'accuracy': 1.0,
#  'duration': 177.45138502120972,
#  'f1': 1.0,
#  'loss': 1.0437647700309753,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00220: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00309: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00360: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00411: reducing learning rate of group 0 to 1.0000e-04.
# 82 PLAID
# {'accuracy': 0.7337057728119181,
#  'duration': 841.2319760322571,
#  'f1': 0.5107261081860726,
#  'loss': 1.8064032793045044,
#  'precision': 0.48641401298520515,
#  'recall': 0.5561124226835811}
# Epoch 00203: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00256: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00307: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00358: reducing learning rate of group 0 to 1.0000e-04.
# 84 Phoneme
# {'accuracy': 0.8551401869158879,
#  'duration': 802.0187153816223,
#  'f1': 0.5497833220910144,
#  'loss': 2.872476816177368,
#  'precision': 0.5318070818070819,
#  'recall': 0.589420195189426}
# Epoch 00295: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00346: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00478: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00529: reducing learning rate of group 0 to 1.0000e-04.
# 86 PigAirwayPressure
# {'accuracy': 0.8269230769230769,
#  'duration': 302.5996639728546,
#  'f1': 0.766117216117216,
#  'loss': 3.1693495512008667,
#  'precision': 0.732051282051282,
#  'recall': 0.8269230769230769}
# Epoch 00376: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00800: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00942: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00993: reducing learning rate of group 0 to 1.0000e-04.
# 88 PigCVP
# {'accuracy': 1.0,
#  'duration': 302.89323115348816,
#  'f1': 1.0,
#  'loss': 2.9842129945755005,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00085: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00142: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00193: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00244: reducing learning rate of group 0 to 1.0000e-04.
# 90 PowerCons
# {'accuracy': 1.0,
#  'duration': 394.7914707660675,
#  'f1': 1.0,
#  'loss': 0.3132724662621816,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00117: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00168: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00219: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00270: reducing learning rate of group 0 to 1.0000e-04.
# 92 ProximalPhalanxOutlineCorrect
# {'accuracy': 0.9833333333333333,
#  'duration': 499.190411567688,
#  'f1': 0.9807445442875481,
#  'loss': 0.32959176003932955,
#  'precision': 0.9864422627395979,
#  'recall': 0.9755725966177442}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00104: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00155: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00206: reducing learning rate of group 0 to 1.0000e-04.
# 94 RefrigerationDevices
# {'accuracy': 1.0,
#  'duration': 340.155677318573,
#  'f1': 1.0,
#  'loss': 0.5514671007792155,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00154: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.0000e-04.
# 96 ScreenType
# {'accuracy': 0.9973333333333333,
#  'duration': 339.43865609169006,
#  'f1': 0.997333290665984,
#  'loss': 0.5541256169478098,
#  'precision': 0.9973544973544973,
#  'recall': 0.9973333333333333}
# Epoch 00151: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00202: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00253: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00304: reducing learning rate of group 0 to 1.0000e-04.
# 98 SemgHandMovementCh2
# {'accuracy': 0.6977777777777778,
#  'duration': 830.1553337574005,
#  'f1': 0.6583468262525851,
#  'loss': 1.378971979022026,
#  'precision': 0.6898669386688466,
#  'recall': 0.6977777777777777}
# Epoch 00736: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00832: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00883: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00934: reducing learning rate of group 0 to 1.0000e-04.
# 100 ShakeGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 55.493075370788574,
#  'f1': 1.0,
#  'loss': 1.4612188339233398,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00333: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00695: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00746: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00864: reducing learning rate of group 0 to 1.0000e-04.
# 102 ShapesAll
# {'accuracy': 0.995,
#  'duration': 466.2470004558563,
#  'f1': 0.9949874686716792,
#  'loss': 3.127307963371277,
#  'precision': 0.9954545454545455,
#  'recall': 0.995}
# Epoch 00094: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00145: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00196: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00247: reducing learning rate of group 0 to 1.0000e-04.
# 104 SmoothSubspace
# {'accuracy': 1.0,
#  'duration': 137.17399549484253,
#  'f1': 1.0,
#  'loss': 0.5516168475151062,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00564: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00633: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00684: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00735: reducing learning rate of group 0 to 1.0000e-04.
# 106 SonyAIBORobotSurface2
# {'accuracy': 1.0,
#  'duration': 194.40759682655334,
#  'f1': 1.0,
#  'loss': 0.3132709860801697,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00187: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00287: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00390: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00441: reducing learning rate of group 0 to 1.0000e-04.
# 108 Strawberry
# {'accuracy': 0.9951060358890701,
#  'duration': 428.58644914627075,
#  'f1': 0.9946553903831902,
#  'loss': 0.31796458959579466,
#  'precision': 0.9962216624685138,
#  'recall': 0.9931506849315068}
# 110 Symbols
# {'accuracy': 1.0,
#  'duration': 206.41979002952576,
#  'f1': 1.0,
#  'loss': 1.0436145067214966,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00055: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00106: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00157: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.0000e-04.
# 112 ToeSegmentation1
# {'accuracy': 1.0,
#  'duration': 88.94918870925903,
#  'f1': 1.0,
#  'loss': 0.3132934272289276,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00296: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00371: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00422: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00473: reducing learning rate of group 0 to 1.0000e-04.
# 114 Trace
# {'accuracy': 1.0,
#  'duration': 99.43726897239685,
#  'f1': 1.0,
#  'loss': 0.7436875104904175,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00139: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00190: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00241: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00292: reducing learning rate of group 0 to 1.0000e-04.
# 116 TwoPatterns
# {'accuracy': 1.0,
#  'duration': 2569.9532356262207,
#  'f1': 1.0,
#  'loss': 0.7436689808964729,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00360: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00411: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00462: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00513: reducing learning rate of group 0 to 1.0000e-04.
# 118 UWaveGestureLibraryAll
# {'accuracy': 1.0,
#  'duration': 1825.7659840583801,
#  'f1': 1.0,
#  'loss': 1.2740226217678614,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00273: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00324: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00426: reducing learning rate of group 0 to 1.0000e-04.
# 120 UWaveGestureLibraryY
# {'accuracy': 0.9933035714285714,
#  'duration': 1080.249109506607,
#  'f1': 0.9935621155530084,
#  'loss': 1.2806665641920907,
#  'precision': 0.9938390313390313,
#  'recall': 0.9933441673599155}
# Epoch 00126: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00177: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00276: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00401: reducing learning rate of group 0 to 1.0000e-04.
# 122 Wafer
# {'accuracy': 1.0,
#  'duration': 2912.1511981487274,
#  'f1': 1.0,
#  'loss': 0.3132620472460985,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00295: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00346: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00397: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00448: reducing learning rate of group 0 to 1.0000e-04.
# 124 WordSynonyms
# {'accuracy': 0.8576779026217228,
#  'duration': 281.438045501709,
#  'f1': 0.6076542545287107,
#  'loss': 2.4178848266601562,
#  'precision': 0.5588673431831327,
#  'recall': 0.68}
# Epoch 00093: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00144: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00195: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00246: reducing learning rate of group 0 to 1.0000e-04.
# 126 WormsTwoClass
# {'accuracy': 1.0,
#  'duration': 178.50327157974243,
#  'f1': 1.0,
#  'loss': 0.31331855058670044,
#  'precision': 1.0,
#  'recall': 1.0}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
