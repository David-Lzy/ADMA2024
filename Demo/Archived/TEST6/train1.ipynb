# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST5

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try6_c_Classfier

# %%
DEVICE = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=1)

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 0:
        continue
    trainer = Trainer(
        dataset=i_dataset,
        epoch=1000,
        model=model_class,
        device=DEVICE,
    )
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00615: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00721: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00772: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00891: reducing learning rate of group 0 to 1.0000e-04.
# 1 Adiac
# {'accuracy': 0.7923076923076923,
#  'duration': 799.7507529258728,
#  'f1': 0.6700558112792295,
#  'loss': 2.861836705889021,
#  'precision': 0.6261899291911569,
#  'recall': 0.7362476112476113}
# Epoch 00225: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00276: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00327: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00378: reducing learning rate of group 0 to 1.0000e-04.
# 3 AllGestureWiimoteY
# {'accuracy': 1.0,
#  'duration': 276.94590425491333,
#  'f1': 1.0,
#  'loss': 1.461224102973938,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00073: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00124: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00175: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00226: reducing learning rate of group 0 to 1.0000e-04.
# 5 ArrowHead
# {'accuracy': 1.0,
#  'duration': 46.157174825668335,
#  'f1': 1.0,
#  'loss': 0.5515466332435608,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00141: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00192: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00243: reducing learning rate of group 0 to 1.2500e-04.
# 7 Beef
# {'accuracy': 1.0,
#  'duration': 30.64127492904663,
#  'f1': 1.0,
#  'loss': 0.9050515294075012,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00070: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00121: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00172: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00223: reducing learning rate of group 0 to 1.0000e-04.
# 9 BirdChicken
# {'accuracy': 1.0,
#  'duration': 29.641538619995117,
#  'f1': 1.0,
#  'loss': 0.3132990598678589,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00143: reducing learning rate of group 0 to 5.0000e-04.
# 11 Car
# {'accuracy': 1.0,
#  'duration': 50.89978289604187,
#  'f1': 1.0,
#  'loss': 0.7437116503715515,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00320: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00371: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00422: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00516: reducing learning rate of group 0 to 1.0000e-04.
# 13 ChlorineConcentration
# {'accuracy': 0.9892933618843683,
#  'duration': 1314.7974894046783,
#  'f1': 0.986695331728925,
#  'loss': 0.561239555478096,
#  'precision': 0.9911995898838004,
#  'recall': 0.9824240087397982}
# Epoch 00269: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00321: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00372: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00423: reducing learning rate of group 0 to 1.0000e-04.
# 15 Coffee
# {'accuracy': 1.0,
#  'duration': 34.91492795944214,
#  'f1': 1.0,
#  'loss': 0.31327685713768005,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00266: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00346: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00397: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00448: reducing learning rate of group 0 to 1.0000e-04.
# 17 CricketX
# {'accuracy': 1.0,
#  'duration': 208.94107103347778,
#  'f1': 1.0,
#  'loss': 1.6190951551709856,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00211: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00286: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00355: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00417: reducing learning rate of group 0 to 1.0000e-04.
# 19 CricketZ
# {'accuracy': 0.9974358974358974,
#  'duration': 198.93440318107605,
#  'f1': 0.9975825099852847,
#  'loss': 1.6238776785986764,
#  'precision': 0.9975490196078431,
#  'recall': 0.9976851851851851}
# 21 DiatomSizeReduction
# {'accuracy': 1.0,
#  'duration': 66.31902146339417,
#  'f1': 1.0,
#  'loss': 0.7436893582344055,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00079: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00130: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00181: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00232: reducing learning rate of group 0 to 1.0000e-04.
# 23 DistalPhalanxOutlineCorrect
# {'accuracy': 0.985,
#  'duration': 414.9075257778168,
#  'f1': 0.9839273755487761,
#  'loss': 0.3282743215560913,
#  'precision': 0.983484197880363,
#  'recall': 0.9843772343772343}
# Epoch 00072: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00123: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00174: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.0000e-04.
# 25 DodgerLoopDay
# {'accuracy': 1.0,
#  'duration': 59.067137718200684,
#  'f1': 1.0,
#  'loss': 1.1691760420799255,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00118: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00169: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.0000e-04.
# 27 DodgerLoopWeekend
# {'accuracy': 1.0,
#  'duration': 47.174943685531616,
#  'f1': 1.0,
#  'loss': 0.31330546736717224,
#  'precision': 1.0,
#  'recall': 1.0}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
