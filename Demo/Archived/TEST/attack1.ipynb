# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 __file__ = get_ipython().run_line_magic('pwd', '')
#       4 sys.path.append(os.path.dirname(os.path.dirname(__file__)))
# ----> 5 from __init__ import *
#       6 print('pwd:', __file__)
#       7 logger.setLevel(logging.INFO)
#
# ModuleNotFoundError: No module named '__init__'

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES

# %%
trainer = Trainer(dataset=part_DATASETs[0], epoch=1000)

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
for i, i_dataset in enumerate(part_DATASETs):
    attacker = attack_model(
        train_method_path=trainer.method_path,
        dataset=i_dataset,
    )

    attacker.perturb_all(
        to_device=True,
        override=True,
    )
    try:
        print(i, i_dataset)
        pprint(attacker.data)
        print("\n")
    except AttributeError:
        pass
# Out:
# Classifier_INCEPTION
# 0 ACSF1
# {'ASR': 0.73,
#  'Count_Fail': 27,
#  'Count_Success': 73,
#  'duration': 121.59518074989319,
#  'mean_failure_distance': 10.77358,
#  'mean_success_distance': 6.8575006,
#  'overall_mean_distance': 7.914842}
#
#
# Classifier_INCEPTION
# 1 Adiac
# {'ASR': 0.948849104859335,
#  'Count_Fail': 20,
#  'Count_Success': 371,
#  'duration': 755.5378940105438,
#  'mean_failure_distance': 0.6788371,
#  'mean_success_distance': 0.3831639,
#  'overall_mean_distance': 0.3982879}
#
#
# Classifier_INCEPTION
# 2 AllGestureWiimoteX
# {'ASR': 0.8428571428571429,
#  'Count_Fail': 110,
#  'Count_Success': 590,
#  'duration': 376.39142084121704,
#  'mean_failure_distance': 0.5433765,
#  'mean_success_distance': 1.1831052,
#  'overall_mean_distance': 1.0825764}
#
#
# Classifier_INCEPTION
# 3 AllGestureWiimoteY
# {'ASR': 0.9157142857142857,
#  'Count_Fail': 59,
#  'Count_Success': 641,
#  'duration': 376.12328267097473,
#  'mean_failure_distance': 0.25257996,
#  'mean_success_distance': 0.61270773,
#  'overall_mean_distance': 0.5823541}
#
#
# Classifier_INCEPTION
# 4 AllGestureWiimoteZ
# {'ASR': 0.88,
#  'Count_Fail': 84,
#  'Count_Success': 616,
#  'duration': 375.034654378891,
#  'mean_failure_distance': 0.7697986,
#  'mean_success_distance': 1.318291,
#  'overall_mean_distance': 1.252472}
#
#
# Classifier_INCEPTION
# 5 ArrowHead
# {'ASR': 0.8971428571428571,
#  'Count_Fail': 18,
#  'Count_Success': 157,
#  'duration': 96.03406524658203,
#  'mean_failure_distance': 1.9623059,
#  'mean_success_distance': 1.4483014,
#  'overall_mean_distance': 1.5011705}
#
#
# Classifier_INCEPTION
# 6 BME
# {'ASR': 0.4666666666666667,
#  'Count_Fail': 80,
#  'Count_Success': 70,
#  'duration': 271.6111514568329,
#  'mean_failure_distance': 1.0479221,
#  'mean_success_distance': 1.0220131,
#  'overall_mean_distance': 1.0358313}
#
#
# Classifier_INCEPTION
# 7 Beef
# {'ASR': 0.9,
#  'Count_Fail': 3,
#  'Count_Success': 27,
#  'duration': 32.5724458694458,
#  'mean_failure_distance': 1.4174699,
#  'mean_success_distance': 1.1772867,
#  'overall_mean_distance': 1.2013049}
#
#
# Classifier_INCEPTION
# 8 BeetleFly
# {'ASR': 0.75,
#  'Count_Fail': 5,
#  'Count_Success': 15,
#  'duration': 32.77176284790039,
#  'mean_failure_distance': 4.613533,
#  'mean_success_distance': 4.1434703,
#  'overall_mean_distance': 4.260987}
#
#
# Classifier_INCEPTION
# /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# 9 BirdChicken
# {'ASR': 1.0,
#  'Count_Fail': 0,
#  'Count_Success': 20,
#  'duration': 32.89742064476013,
#  'mean_failure_distance': nan,
#  'mean_success_distance': 0.7759176,
#  'overall_mean_distance': 0.7759176}
#
#
# Classifier_INCEPTION
# 10 CBF
# {'ASR': 0.03,
#  'Count_Fail': 873,
#  'Count_Success': 27,
#  'duration': 1707.918247461319,
#  'mean_failure_distance': 1.194407,
#  'mean_success_distance': 1.2176676,
#  'overall_mean_distance': 1.1951048}
#
#
# Classifier_INCEPTION
# 11 Car
# {'ASR': 0.9833333333333333,
#  'Count_Fail': 1,
#  'Count_Success': 59,
#  'duration': 36.450093269348145,
#  'mean_failure_distance': 0.76529276,
#  'mean_success_distance': 1.3339255,
#  'overall_mean_distance': 1.3244482}
#
#
# Classifier_INCEPTION
# 12 Chinatown
# {'ASR': 0.0,
#  'Count_Fail': 343,
#  'Count_Success': 0,
#  'duration': 197.6983642578125,
#  'mean_failure_distance': 0.113802865,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.113802865}
#
#
# Classifier_INCEPTION
# 13 ChlorineConcentration
# {'ASR': 0.8703125,
#  'Count_Fail': 498,
#  'Count_Success': 3342,
#  'duration': 7239.243488788605,
#  'mean_failure_distance': 0.009384707,
#  'mean_success_distance': 0.15513831,
#  'overall_mean_distance': 0.1362359}
#
#
# Classifier_INCEPTION
# 14 CinCECGTorso
# {'ASR': 0.9840579710144928,
#  'Count_Fail': 22,
#  'Count_Success': 1358,
#  'duration': 1889.0674064159393,
#  'mean_failure_distance': 0.14955176,
#  'mean_success_distance': 1.6400335,
#  'overall_mean_distance': 1.6162724}
#
#
# Classifier_INCEPTION
# 15 Coffee
# {'ASR': 1.0,
#  'Count_Fail': 0,
#  'Count_Success': 28,
#  'duration': 33.649179458618164,
#  'mean_failure_distance': nan,
#  'mean_success_distance': 1.015267,
#  'overall_mean_distance': 1.015267}
#
#
# Classifier_INCEPTION
# 16 Computers
# {'ASR': 0.896,
#  'Count_Fail': 26,
#  'Count_Success': 224,
#  'duration': 166.0052056312561,
#  'mean_failure_distance': 0.41439503,
#  'mean_success_distance': 1.2637788,
#  'overall_mean_distance': 1.1754428}
#
#
# Classifier_INCEPTION
# 17 CricketX
# {'ASR': 0.3076923076923077,
#  'Count_Fail': 270,
#  'Count_Success': 120,
#  'duration': 237.94792318344116,
#  'mean_failure_distance': 2.1042035,
#  'mean_success_distance': 2.3018215,
#  'overall_mean_distance': 2.165009}
#
#
# Classifier_INCEPTION
# 18 CricketY
# {'ASR': 0.4205128205128205,
#  'Count_Fail': 226,
#  'Count_Success': 164,
#  'duration': 239.8743793964386,
#  'mean_failure_distance': 2.3459027,
#  'mean_success_distance': 2.3844225,
#  'overall_mean_distance': 2.3621008}
#
#
# Classifier_INCEPTION
# 19 CricketZ
# {'ASR': 0.3128205128205128,
#  'Count_Fail': 268,
#  'Count_Success': 122,
#  'duration': 236.25928664207458,
#  'mean_failure_distance': 2.031904,
#  'mean_success_distance': 2.2893748,
#  'overall_mean_distance': 2.112446}
#
#
# Classifier_INCEPTION
# 20 Crop
# {'ASR': 0.6273214285714286,
#  'Count_Fail': 6261,
#  'Count_Success': 10539,
#  'duration': 11418.494718074799,
#  'mean_failure_distance': 0.002682902,
#  'mean_success_distance': 0.025858136,
#  'overall_mean_distance': 0.017221224}
#
#
# Classifier_INCEPTION
# 21 DiatomSizeReduction
# {'ASR': 0.9738562091503268,
#  'Count_Fail': 8,
#  'Count_Success': 298,
#  'duration': 171.939799785614,
#  'mean_failure_distance': 3.108974,
#  'mean_success_distance': 2.308679,
#  'overall_mean_distance': 2.3296018}
#
#
# Classifier_INCEPTION
# 22 DistalPhalanxOutlineAgeGroup
# {'ASR': 0.8848920863309353,
#  'Count_Fail': 16,
#  'Count_Success': 123,
#  'duration': 125.87012839317322,
#  'mean_failure_distance': 0.009690921,
#  'mean_success_distance': 0.1669391,
#  'overall_mean_distance': 0.14883856}
#
#
# Classifier_INCEPTION
# 23 DistalPhalanxOutlineCorrect
# {'ASR': 0.8731884057971014,
#  'Count_Fail': 35,
#  'Count_Success': 241,
#  'duration': 217.10860776901245,
#  'mean_failure_distance': 0.0005877495,
#  'mean_success_distance': 0.058281366,
#  'overall_mean_distance': 0.05096514}
#
#
# Classifier_INCEPTION
# 24 DistalPhalanxTW
# {'ASR': 0.9424460431654677,
#  'Count_Fail': 8,
#  'Count_Success': 131,
#  'duration': 125.68651056289673,
#  'mean_failure_distance': 0.2733873,
#  'mean_success_distance': 0.32206848,
#  'overall_mean_distance': 0.3192667}
#
#
# Classifier_INCEPTION
# 25 DodgerLoopDay
# {'ASR': 0.075,
#  'Count_Fail': 74,
#  'Count_Success': 6,
#  'duration': 69.84710741043091,
#  'mean_failure_distance': 2.7990935,
#  'mean_success_distance': 2.8285189,
#  'overall_mean_distance': 2.8013005}
#
#
# Classifier_INCEPTION
# 26 DodgerLoopGame
# {'ASR': 0.11594202898550725,
#  'Count_Fail': 122,
#  'Count_Success': 16,
#  'duration': 104.93899393081665,
#  'mean_failure_distance': 2.4843478,
#  'mean_success_distance': 2.8256807,
#  'overall_mean_distance': 2.5239222}
#
#
# Classifier_INCEPTION
# 27 DodgerLoopWeekend
# {'ASR': 0.007246376811594203,
#  'Count_Fail': 137,
#  'Count_Success': 1,
#  'duration': 105.2444224357605,
#  'mean_failure_distance': 1.9307554,
#  'mean_success_distance': 2.850373,
#  'overall_mean_distance': 1.937419}
#
#
# Classifier_INCEPTION
# 28 ECG200
# {'ASR': 0.45,
#  'Count_Fail': 55,
#  'Count_Success': 45,
#  'duration': 203.81330633163452,
#  'mean_failure_distance': 0.85365325,
#  'mean_success_distance': 0.7601848,
#  'overall_mean_distance': 0.8115924}
#
#
# Classifier_INCEPTION
# 29 ECG5000
# {'ASR': 0.24488888888888888,
#  'Count_Fail': 3398,
#  'Count_Success': 1102,
#  'duration': 8473.475479602814,
#  'mean_failure_distance': 0.24460372,
#  'mean_success_distance': 1.1435492,
#  'overall_mean_distance': 0.46474543}
#
#
# Classifier_INCEPTION
# 30 ECGFiveDays
# {'ASR': 0.027874564459930314,
#  'Count_Fail': 837,
#  'Count_Success': 24,
#  'duration': 1643.7437970638275,
#  'mean_failure_distance': 1.2256824,
#  'mean_success_distance': 1.2349364,
#  'overall_mean_distance': 1.2259402}
#
#
# Classifier_INCEPTION
# 31 EOGHorizontalSignal
# {'ASR': 0.022099447513812154,
#  'Count_Fail': 354,
#  'Count_Success': 8,
#  'duration': 380.10658860206604,
#  'mean_failure_distance': 7.1673703,
#  'mean_success_distance': 10.267427,
#  'overall_mean_distance': 7.2358794}
#
#
# Classifier_INCEPTION
# 32 EOGVerticalSignal
# {'ASR': 0.0055248618784530384,
#  'Count_Fail': 360,
#  'Count_Success': 2,
#  'duration': 379.7385370731354,
#  'mean_failure_distance': 7.781054,
#  'mean_success_distance': 6.3424215,
#  'overall_mean_distance': 7.7731056}
#
#
# Classifier_INCEPTION
# 33 Earthquakes
# {'ASR': 0.8273381294964028,
#  'Count_Fail': 24,
#  'Count_Success': 115,
#  'duration': 109.28784775733948,
#  'mean_failure_distance': 3.0623894,
#  'mean_success_distance': 3.693164,
#  'overall_mean_distance': 3.5842533}
#
#
# Classifier_INCEPTION
# 34 ElectricDevices
# {'ASR': 0.3576708598106601,
#  'Count_Fail': 4953,
#  'Count_Success': 2758,
#  'duration': 14412.123478889465,
#  'mean_failure_distance': 0.056627266,
#  'mean_success_distance': 0.17865437,
#  'overall_mean_distance': 0.100272804}
#
#
# Classifier_INCEPTION
# 35 EthanolLevel
# {'ASR': 0.934,
#  'Count_Fail': 33,
#  'Count_Success': 467,
#  'duration': 720.9540853500366,
#  'mean_failure_distance': 0.038905796,
#  'mean_success_distance': 0.23201796,
#  'overall_mean_distance': 0.21927255}
#
#
# Classifier_INCEPTION
# 36 FaceAll
# {'ASR': 0.11893491124260355,
#  'Count_Fail': 1489,
#  'Count_Success': 201,
#  'duration': 3210.75234913826,
#  'mean_failure_distance': 0.4919692,
#  'mean_success_distance': 1.1361817,
#  'overall_mean_distance': 0.56858855}
#
#
# Classifier_INCEPTION
# 37 FaceFour
# {'ASR': 0.4318181818181818,
#  'Count_Fail': 50,
#  'Count_Success': 38,
#  'duration': 72.47600030899048,
#  'mean_failure_distance': 3.147271,
#  'mean_success_distance': 3.0788121,
#  'overall_mean_distance': 3.1177084}
#
#
# Classifier_INCEPTION
# 38 FacesUCR
# {'ASR': 0.05609756097560976,
#  'Count_Fail': 1935,
#  'Count_Success': 115,
#  'duration': 3901.961950302124,
#  'mean_failure_distance': 1.1213173,
#  'mean_success_distance': 1.2312258,
#  'overall_mean_distance': 1.1274829}
#
#
# Classifier_INCEPTION
# 39 FiftyWords
# {'ASR': 0.33406593406593404,
#  'Count_Fail': 303,
#  'Count_Success': 152,
#  'duration': 292.6932632923126,
#  'mean_failure_distance': 2.1353273,
#  'mean_success_distance': 2.2419205,
#  'overall_mean_distance': 2.1709363}
#
#
# Classifier_INCEPTION
# 40 Fish
# {'ASR': 0.9714285714285714,
#  'Count_Fail': 5,
#  'Count_Success': 170,
#  'duration': 110.93258833885193,
#  'mean_failure_distance': 0.65374947,
#  'mean_success_distance': 2.0236127,
#  'overall_mean_distance': 1.9844737}
#
#
# Classifier_INCEPTION
# 41 FordA
# {'ASR': 0.2446969696969697,
#  'Count_Fail': 997,
#  'Count_Success': 323,
#  'duration': 775.2682871818542,
#  'mean_failure_distance': 0.0005896814,
#  'mean_success_distance': 0.88220745,
#  'overall_mean_distance': 0.21631888}
#
#
# Classifier_INCEPTION
# 42 FordB
# {'ASR': 0.47530864197530864,
#  'Count_Fail': 425,
#  'Count_Success': 385,
#  'duration': 484.97313499450684,
#  'mean_failure_distance': 0.0006733205,
#  'mean_success_distance': 0.75390345,
#  'overall_mean_distance': 0.3586901}
#
#
# Classifier_INCEPTION
# 43 FreezerRegularTrain
# {'ASR': 0.4968421052631579,
#  'Count_Fail': 1434,
#  'Count_Success': 1416,
#  'duration': 1665.7691926956177,
#  'mean_failure_distance': 0.0070130224,
#  'mean_success_distance': 0.48417288,
#  'overall_mean_distance': 0.24408615}
#
#
# Classifier_INCEPTION
# 44 FreezerSmallTrain
# {'ASR': 0.6831578947368421,
#  'Count_Fail': 903,
#  'Count_Success': 1947,
#  'duration': 1666.0212342739105,
#  'mean_failure_distance': 2.5507905,
#  'mean_success_distance': 1.8369066,
#  'overall_mean_distance': 2.0630949}
#
#
# Classifier_INCEPTION
# 45 Fungi
# {'ASR': 0.016129032258064516,
#  'Count_Fail': 183,
#  'Count_Success': 3,
#  'duration': 366.7795534133911,
#  'mean_failure_distance': 1.5762237,
#  'mean_success_distance': 1.7621094,
#  'overall_mean_distance': 1.579222}
#
#
# Classifier_INCEPTION
# 46 GestureMidAirD1
# {'ASR': 0.015384615384615385,
#  'Count_Fail': 128,
#  'Count_Success': 2,
#  'duration': 111.2905044555664,
#  'mean_failure_distance': 2.5031762,
#  'mean_success_distance': 3.0439513,
#  'overall_mean_distance': 2.511496}
#
#
# Classifier_INCEPTION
# 47 GestureMidAirD2
# {'ASR': 0.015384615384615385,
#  'Count_Fail': 128,
#  'Count_Success': 2,
#  'duration': 111.93189430236816,
#  'mean_failure_distance': 2.1995106,
#  'mean_success_distance': 3.5447035,
#  'overall_mean_distance': 2.220206}
#
#
# Classifier_INCEPTION
# 48 GestureMidAirD3
# {'ASR': 0.06153846153846154,
#  'Count_Fail': 122,
#  'Count_Success': 8,
#  'duration': 112.18967580795288,
#  'mean_failure_distance': 3.250163,
#  'mean_success_distance': 3.2715614,
#  'overall_mean_distance': 3.2514799}
#
#
# Classifier_INCEPTION
# 49 GesturePebbleZ1
# {'ASR': 0.011627906976744186,
#  'Count_Fail': 170,
#  'Count_Success': 2,
#  'duration': 113.81063199043274,
#  'mean_failure_distance': 3.4451473,
#  'mean_success_distance': 0.7547825,
#  'overall_mean_distance': 3.413864}
#
#
# Classifier_INCEPTION
# 50 GesturePebbleZ2
# {'ASR': 0.05063291139240506,
#  'Count_Fail': 150,
#  'Count_Success': 8,
#  'duration': 114.03586912155151,
#  'mean_failure_distance': 3.566202,
#  'mean_success_distance': 3.6289885,
#  'overall_mean_distance': 3.5693808}
#
#
# Classifier_INCEPTION
# 51 GunPoint
# {'ASR': 0.7733333333333333,
#  'Count_Fail': 34,
#  'Count_Success': 116,
#  'duration': 281.6824781894684,
#  'mean_failure_distance': 1.3430835,
#  'mean_success_distance': 0.952755,
#  'overall_mean_distance': 1.0412295}
#
#
# Classifier_INCEPTION
# 52 GunPointAgeSpan
# {'ASR': 0.0031645569620253164,
#  'Count_Fail': 315,
#  'Count_Success': 1,
#  'duration': 607.8347678184509,
#  'mean_failure_distance': 0.54861915,
#  'mean_success_distance': 1.4596565,
#  'overall_mean_distance': 0.55150217}
#
#
# Classifier_INCEPTION
# 53 GunPointMaleVersusFemale
# {'ASR': 0.0,
#  'Count_Fail': 316,
#  'Count_Success': 0,
#  'duration': 608.4760196208954,
#  'mean_failure_distance': 0.13874108,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.13874108}
#
#
# Classifier_INCEPTION
# 54 GunPointOldVersusYoung
# {'ASR': 0.0,
#  'Count_Fail': 315,
#  'Count_Success': 0,
#  'duration': 610.1342833042145,
#  'mean_failure_distance': 0.026387766,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.026387766}
#
#
# Classifier_INCEPTION
# 55 Ham
# {'ASR': 0.9714285714285714,
#  'Count_Fail': 3,
#  'Count_Success': 102,
#  'duration': 76.59881496429443,
#  'mean_failure_distance': 3.7476985,
#  'mean_success_distance': 2.2167678,
#  'overall_mean_distance': 2.2605088}
#
#
# Classifier_INCEPTION
# 56 HandOutlines
# {'ASR': 0.927027027027027,
#  'Count_Fail': 27,
#  'Count_Success': 343,
#  'duration': 813.4185063838959,
#  'mean_failure_distance': 0.0027390984,
#  'mean_success_distance': 0.24066278,
#  'overall_mean_distance': 0.22330078}
#
#
# Classifier_INCEPTION
# 57 Haptics
# {'ASR': 0.9967532467532467,
#  'Count_Fail': 1,
#  'Count_Success': 307,
#  'duration': 285.4875154495239,
#  'mean_failure_distance': 2.7931645,
#  'mean_success_distance': 1.8877411,
#  'overall_mean_distance': 1.8906809}
#
#
# Classifier_INCEPTION
# 58 Herring
# {'ASR': 1.0,
#  'Count_Fail': 0,
#  'Count_Success': 64,
#  'duration': 38.271079778671265,
#  'mean_failure_distance': nan,
#  'mean_success_distance': 0.4630163,
#  'overall_mean_distance': 0.4630163}
#
#
# Classifier_INCEPTION
# 59 HouseTwenty
# {'ASR': 0.0,
#  'Count_Fail': 119,
#  'Count_Success': 0,
#  'duration': 191.1742401123047,
#  'mean_failure_distance': 5.8434677,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 5.8434677}
#
#
# Classifier_INCEPTION
# 60 InlineSkate
# {'ASR': 0.9927272727272727,
#  'Count_Fail': 4,
#  'Count_Success': 546,
#  'duration': 849.4927890300751,
#  'mean_failure_distance': 0.03185789,
#  'mean_success_distance': 0.26970235,
#  'overall_mean_distance': 0.26797253}
#
#
# Classifier_INCEPTION
# 61 InsectEPGRegularTrain
# {'ASR': 0.08032128514056225,
#  'Count_Fail': 229,
#  'Count_Success': 20,
#  'duration': 160.31927704811096,
#  'mean_failure_distance': 1.466697,
#  'mean_success_distance': 6.0051455,
#  'overall_mean_distance': 1.8312309}
#
#
# Classifier_INCEPTION
# 62 InsectEPGSmallTrain
# {'ASR': 0.09236947791164658,
#  'Count_Fail': 226,
#  'Count_Success': 23,
#  'duration': 160.412433385849,
#  'mean_failure_distance': 1.4845017,
#  'mean_success_distance': 6.009464,
#  'overall_mean_distance': 1.90247}
#
#
# Classifier_INCEPTION
# 63 InsectWingbeatSound
# {'ASR': 0.6954545454545454,
#  'Count_Fail': 603,
#  'Count_Success': 1377,
#  'duration': 1177.9774465560913,
#  'mean_failure_distance': 1.8420042,
#  'mean_success_distance': 1.8210566,
#  'overall_mean_distance': 1.827436}
#
#
# Classifier_INCEPTION
# 64 ItalyPowerDemand
# {'ASR': 0.24295432458697766,
#  'Count_Fail': 779,
#  'Count_Success': 250,
#  'duration': 667.9539172649384,
#  'mean_failure_distance': 0.22533365,
#  'mean_success_distance': 0.21303785,
#  'overall_mean_distance': 0.22234634}
#
#
# Classifier_INCEPTION
# 65 LargeKitchenAppliances
# {'ASR': 0.584,
#  'Count_Fail': 156,
#  'Count_Success': 219,
#  'duration': 261.4700300693512,
#  'mean_failure_distance': 2.8129616,
#  'mean_success_distance': 4.7218447,
#  'overall_mean_distance': 3.9277494}
#
#
# Classifier_INCEPTION
# 66 Lightning2
# {'ASR': 0.8360655737704918,
#  'Count_Fail': 10,
#  'Count_Success': 51,
#  'duration': 40.972426652908325,
#  'mean_failure_distance': 4.9513803,
#  'mean_success_distance': 3.9828472,
#  'overall_mean_distance': 4.1416235}
#
#
# Classifier_INCEPTION
# 67 Lightning7
# {'ASR': 0.2054794520547945,
#  'Count_Fail': 58,
#  'Count_Success': 15,
#  'duration': 79.89516615867615,
#  'mean_failure_distance': 2.7271526,
#  'mean_success_distance': 2.660924,
#  'overall_mean_distance': 2.7135441}
#
#
# Classifier_INCEPTION
# 68 Mallat
# {'ASR': 0.9257995735607676,
#  'Count_Fail': 174,
#  'Count_Success': 2171,
#  'duration': 2018.007788658142,
#  'mean_failure_distance': 6.7132373,
#  'mean_success_distance': 5.920276,
#  'overall_mean_distance': 5.9791145}
#
#
# Classifier_INCEPTION
# 69 Meat
# {'ASR': 1.0,
#  'Count_Fail': 0,
#  'Count_Success': 60,
#  'duration': 40.30968499183655,
#  'mean_failure_distance': nan,
#  'mean_success_distance': 0.18013011,
#  'overall_mean_distance': 0.18013011}
#
#
# Classifier_INCEPTION
# 70 MedicalImages
# {'ASR': 0.5697368421052632,
#  'Count_Fail': 327,
#  'Count_Success': 433,
#  'duration': 1455.112239599228,
#  'mean_failure_distance': 0.6522551,
#  'mean_success_distance': 0.67612094,
#  'overall_mean_distance': 0.6658523}
#
#
# Classifier_INCEPTION
# 71 MelbournePedestrian
# {'ASR': 0.0,
#  'Count_Fail': 2439,
#  'Count_Success': 0,
#  'duration': 1583.3930838108063,
#  'mean_failure_distance': 0.024558967,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.024558967}
#
#
# Classifier_INCEPTION
# 72 MiddlePhalanxOutlineAgeGroup
# {'ASR': 1.0,
#  'Count_Fail': 0,
#  'Count_Success': 154,
#  'duration': 140.33975100517273,
#  'mean_failure_distance': nan,
#  'mean_success_distance': 0.05838166,
#  'overall_mean_distance': 0.05838166}
#
#
# Classifier_INCEPTION
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       1 for i, i_dataset in enumerate(part_DATASETs):
#       2     attacker = attack_model(
#       3         train_method_path=trainer.method_path,
#       4         dataset=i_dataset,
#       5     )
# ----> 7     attacker.perturb_all(
#       8         to_device=True,
#       9         override=True,
#      10     )
#      11     try:
#      12         print(i, i_dataset)
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Attack/attacker.py:208, in perturb_all(self, override, to_device)
#     201 def perturb_all(self, override=False, to_device=False):
#     202     _ = folder_contains_files(
#     203         self.out_dir,
#     204         "results.csv",
#     205         "x_perturb.tsv",
#     206         "y_perturb.npy",
#     207         "loss.txt",
# --> 208     )
#     209     if to_device and (not override) and _:
#     210         logging.info(f"Dataset: {self.dataset} exist, skip!")
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Attack/attacker.py:154, in perturb(self)
#     151 self.all_sum_losses = np.zeros(self.epoch)
#     152 self.dist = []
# --> 154 i = 1
#     155 for x, y in self.loader:
#     156     logging.info(f"batch: {i}")
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Attack/mix.py:157, in Mix.__perturb_g__(self, x)
#     154 sum_losses = np.zeros(self.epoch)
#     156 for epoch in range(self.epoch):
# --> 157     loss = self.__loss_function__(x, r, y_target, top1_index)
#     158     optimizer.zero_grad()
#     159     loss.backward()
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Attack/mix.py:144, in Mix.__NoCW_loss_fun__(self, x, r, y_target, top1_index)
#     143 def __NoCW_loss_fun__(self, x, r, y_target, top1_index):
# --> 144     y_pred_adv = self.f(x + r)
#     145     return self.__LOSS__(y_pred_adv, y_target).mean()
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Attack/attacker.py:123, in f(self, x)
#     121 self.model.load_state_dict(self.model_info["model_state_dict"])
#     122 self.model.to(self.device)
# --> 123 self.model.eval()
#     124 self.model_name = os.path.basename(__file__).split(".")[0]
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Train/inception_time.py:169, in Classifier_INCEPTION.__forward_softmax__(self, x)
#     166 shortcut_idx = 0
#     168 for d, layer in enumerate(self.layers):
# --> 169     x = layer(x)
#     171     if self.use_residual and d % 3 == 2:
#     172         x = self.short_cut_layer(x, input_res, shortcut_idx)
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Train/inception_time.py:61, in InceptionModule.forward(self, x)
#      58 if self.use_bottleneck and x.size(1) > 1:
#      59     x = self.bottleneck(x) if hasattr(self, "bottleneck") else x
# ---> 61 conv_list = [conv(x) for conv in self.convs]
#      63 conv_mp_out = self.conv_mp(max_pool_1)
#      64 conv_list.append(conv_mp_out)
#
# File /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Train/inception_time.py:61, in <listcomp>(.0)
#      58 if self.use_bottleneck and x.size(1) > 1:
#      59     x = self.bottleneck(x) if hasattr(self, "bottleneck") else x
# ---> 61 conv_list = [conv(x) for conv in self.convs]
#      63 conv_mp_out = self.conv_mp(max_pool_1)
#      64 conv_list.append(conv_mp_out)
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/torch/nn/modules/padding.py:205, in _ConstantPadNd.forward(self, input)
#     204 def forward(self, input: Tensor) -> Tensor:
# --> 205     return F.pad(input, self.padding, 'constant', self.value)
#
# KeyboardInterrupt:
