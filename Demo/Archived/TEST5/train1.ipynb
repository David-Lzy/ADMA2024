# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST5

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try6_c_Classfier

# %%
DEVICE = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=1)

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 0:
        continue
    trainer = Trainer(
        dataset=i_dataset,
        epoch=1000,
        model=model_class,
        device=DEVICE,
    )
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00228: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00279: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00343: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00457: reducing learning rate of group 0 to 1.0000e-04.
# 1 Adiac
# {'accuracy': 0.3487179487179487,
#  'duration': 907.5812456607819,
#  'f1': 0.23679188351225103,
#  'loss': 3.3231988974979947,
#  'precision': 0.20588694777561325,
#  'recall': 0.3092167592167593}
# Epoch 00219: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00294: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00378: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00429: reducing learning rate of group 0 to 1.0000e-04.
# 3 AllGestureWiimoteY
# {'accuracy': 1.0,
#  'duration': 449.8579556941986,
#  'f1': 1.0,
#  'loss': 1.4617056608200074,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00157: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00217: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00268: reducing learning rate of group 0 to 1.0000e-04.
# 5 ArrowHead
# {'accuracy': 1.0,
#  'duration': 77.64126205444336,
#  'f1': 1.0,
#  'loss': 0.5523859262466431,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00123: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00251: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00302: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00353: reducing learning rate of group 0 to 1.0000e-04.
# 7 Beef
# {'accuracy': 0.9,
#  'duration': 47.21320176124573,
#  'f1': 0.8980952380952381,
#  'loss': 0.9843003749847412,
#  'precision': 0.9166666666666667,
#  'recall': 0.9}
# Epoch 00174: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00256: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00307: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00411: reducing learning rate of group 0 to 1.0000e-04.
# 9 BirdChicken
# {'accuracy': 1.0,
#  'duration': 44.65625596046448,
#  'f1': 1.0,
#  'loss': 0.31330686807632446,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00224: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00275: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00326: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00454: reducing learning rate of group 0 to 1.0000e-04.
# 11 Car
# {'accuracy': 1.0,
#  'duration': 78.39676690101624,
#  'f1': 1.0,
#  'loss': 0.749556839466095,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00348: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00447: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00498: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00549: reducing learning rate of group 0 to 1.0000e-04.
# 13 ChlorineConcentration
# {'accuracy': 0.6167023554603854,
#  'duration': 1883.4646241664886,
#  'f1': 0.45941509573521994,
#  'loss': 0.9294846281409264,
#  'precision': 0.6205475810738968,
#  'recall': 0.452563685588997}
# Epoch 00171: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00239: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00290: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00389: reducing learning rate of group 0 to 1.0000e-04.
# 15 Coffee
# {'accuracy': 1.0,
#  'duration': 45.81737303733826,
#  'f1': 1.0,
#  'loss': 0.31378045678138733,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00298: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00349: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00458: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00509: reducing learning rate of group 0 to 1.0000e-04.
# 17 CricketX
# {'accuracy': 0.9974358974358974,
#  'duration': 320.9041361808777,
#  'f1': 0.997460170861233,
#  'loss': 1.621521302631923,
#  'precision': 0.9976851851851851,
#  'recall': 0.9973118279569894}
# Epoch 00261: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00324: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00411: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00462: reducing learning rate of group 0 to 1.0000e-04.
# 19 CricketZ
# {'accuracy': 0.9974358974358974,
#  'duration': 320.3169288635254,
#  'f1': 0.9973544973544973,
#  'loss': 1.6351346458707536,
#  'precision': 0.9973958333333334,
#  'recall': 0.9973958333333334}
# Epoch 00181: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00324: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00426: reducing learning rate of group 0 to 1.0000e-04.
# 21 DiatomSizeReduction
# {'accuracy': 1.0,
#  'duration': 119.8483555316925,
#  'f1': 1.0,
#  'loss': 0.7438697218894958,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00105: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00162: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00293: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00344: reducing learning rate of group 0 to 1.0000e-04.
# 23 DistalPhalanxOutlineCorrect
# {'accuracy': 0.8683333333333333,
#  'duration': 509.38648748397827,
#  'f1': 0.8569872585905702,
#  'loss': 0.44876657128334047,
#  'precision': 0.8622291021671826,
#  'recall': 0.8527456027456027}
# Epoch 00290: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00341: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00392: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00506: reducing learning rate of group 0 to 1.0000e-04.
# 25 DodgerLoopDay
# {'accuracy': 1.0,
#  'duration': 89.60843992233276,
#  'f1': 1.0,
#  'loss': 1.1656558513641357,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00059: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00110: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00161: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.0000e-04.
# 27 DodgerLoopWeekend
# {'accuracy': 1.0,
#  'duration': 78.65221691131592,
#  'f1': 1.0,
#  'loss': 0.31330087780952454,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00123: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00174: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.0000e-04.
# 29 ECG5000
# {'accuracy': 0.988,
#  'duration': 2059.924131631851,
#  'f1': 0.9591666666666667,
#  'loss': 0.917020782828331,
#  'precision': 0.9934426229508198,
#  'recall': 0.9368421052631579}
# Epoch 00241: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00311: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00362: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00413: reducing learning rate of group 0 to 1.0000e-04.
# 31 EOGHorizontalSignal
# {'accuracy': 0.994475138121547,
#  'duration': 774.4947690963745,
#  'f1': 0.9944862697016074,
#  'loss': 1.6249210834503174,
#  'precision': 0.9947076612903226,
#  'recall': 0.9944444444444445}
# Epoch 00089: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00140: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00224: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00275: reducing learning rate of group 0 to 1.0000e-04.
# 33 Earthquakes
# {'accuracy': 0.9813664596273292,
#  'duration': 299.84966921806335,
#  'f1': 0.9680238331678253,
#  'loss': 0.32772204279899597,
#  'precision': 0.974624060150376,
#  'recall': 0.9617293625914316}
# Epoch 00243: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00294: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00353: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00404: reducing learning rate of group 0 to 1.0000e-04.
# 35 EthanolLevel
# {'accuracy': 0.5059523809523809,
#  'duration': 1439.007574081421,
#  'f1': 0.4939431643090999,
#  'loss': 1.206834688782692,
#  'precision': 0.5021704193354173,
#  'recall': 0.5059523809523809}
# Epoch 00332: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00383: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00434: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00485: reducing learning rate of group 0 to 1.0000e-04.
# 37 FaceFour
# {'accuracy': 1.0,
#  'duration': 66.14407277107239,
#  'f1': 1.0,
#  'loss': 0.74371737241745,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00233: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00412: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00463: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00539: reducing learning rate of group 0 to 1.0000e-04.
# 39 FiftyWords
# {'accuracy': 0.6288888888888889,
#  'duration': 369.2349784374237,
#  'f1': 0.2463867991351654,
#  'loss': 3.358232766389847,
#  'precision': 0.19966976169556502,
#  'recall': 0.33466666666666667}
# Epoch 00092: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00143: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00194: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00245: reducing learning rate of group 0 to 1.0000e-04.
# 41 FordA
# {'accuracy': 0.9983337961677312,
#  'duration': 2867.178171157837,
#  'f1': 0.9983326357042843,
#  'loss': 0.31495690816327143,
#  'precision': 0.9983630975349993,
#  'recall': 0.99830464267084}
# Epoch 00107: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00158: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00260: reducing learning rate of group 0 to 1.0000e-04.
# 43 FreezerRegularTrain
# {'accuracy': 0.9533333333333334,
#  'duration': 873.555228471756,
#  'f1': 0.9533146591970122,
#  'loss': 0.37056036790211994,
#  'precision': 0.954059829059829,
#  'recall': 0.9533333333333334}
# Epoch 00481: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00559: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00629: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00680: reducing learning rate of group 0 to 1.0000e-04.
# 45 Fungi
# {'accuracy': 1.0,
#  'duration': 86.23136734962463,
#  'f1': 1.0,
#  'loss': 1.9816632270812988,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00222: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00273: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00324: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.0000e-04.
# 47 GestureMidAirD2
# {'accuracy': 0.875,
#  'duration': 192.0496826171875,
#  'f1': 0.8342055216735523,
#  'loss': 2.442071259021759,
#  'precision': 0.8123931623931624,
#  'recall': 0.875}
# Epoch 00252: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00303: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00404: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00455: reducing learning rate of group 0 to 1.0000e-04.
# 49 GesturePebbleZ1
# {'accuracy': 1.0,
#  'duration': 177.02393341064453,
#  'f1': 1.0,
#  'loss': 1.0442946751912434,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00190: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00269: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00320: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00371: reducing learning rate of group 0 to 1.0000e-04.
# 51 GunPoint
# {'accuracy': 1.0,
#  'duration': 172.09093379974365,
#  'f1': 1.0,
#  'loss': 0.3134113550186157,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00082: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00133: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00348: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00399: reducing learning rate of group 0 to 1.0000e-04.
# 53 GunPointMaleVersusFemale
# {'accuracy': 0.9925925925925926,
#  'duration': 367.3945264816284,
#  'f1': 0.9925664886294807,
#  'loss': 0.3604382375876109,
#  'precision': 0.9930555555555556,
#  'recall': 0.9921875}
# Epoch 00060: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00169: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00271: reducing learning rate of group 0 to 1.0000e-04.
# 55 Ham
# {'accuracy': 1.0,
#  'duration': 112.56335759162903,
#  'f1': 1.0,
#  'loss': 0.3133017420768738,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00130: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00196: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00247: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00298: reducing learning rate of group 0 to 1.0000e-04.
# 57 Haptics
# {'accuracy': 0.9870967741935484,
#  'duration': 407.80622148513794,
#  'f1': 0.9855851875257603,
#  'loss': 0.9168129563331604,
#  'precision': 0.9884033613445379,
#  'recall': 0.9833333333333334}
# Epoch 00085: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00136: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00187: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00238: reducing learning rate of group 0 to 1.0000e-04.
# 59 HouseTwenty
# {'accuracy': 1.0,
#  'duration': 218.52907991409302,
#  'f1': 1.0,
#  'loss': 0.3133198320865631,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00058: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00109: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00160: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00211: reducing learning rate of group 0 to 1.0000e-04.
# 61 InsectEPGRegularTrain
# {'accuracy': 1.0,
#  'duration': 156.11972951889038,
#  'f1': 1.0,
#  'loss': 0.5515074729919434,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00121: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00192: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00243: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00318: reducing learning rate of group 0 to 1.0000e-04.
# 63 InsectWingbeatSound
# {'accuracy': 0.990909090909091,
#  'duration': 655.7087066173553,
#  'f1': 0.9909034055375517,
#  'loss': 1.552734762430191,
#  'precision': 0.9913419913419914,
#  'recall': 0.990909090909091}
# Epoch 00151: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00202: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00253: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00304: reducing learning rate of group 0 to 1.0000e-04.
# 65 LargeKitchenAppliances
# {'accuracy': 0.9946666666666667,
#  'duration': 512.4482581615448,
#  'f1': 0.9946663253114867,
#  'loss': 0.557948887348175,
#  'precision': 0.994750656167979,
#  'recall': 0.9946666666666667}
# Epoch 00171: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00364: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00415: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00466: reducing learning rate of group 0 to 1.0000e-04.
# 67 Lightning7
# {'accuracy': 0.9857142857142858,
#  'duration': 104.29439401626587,
#  'f1': 0.9868131868131869,
#  'loss': 1.1788870096206665,
#  'precision': 0.9928571428571429,
#  'recall': 0.9821428571428571}
# Epoch 00151: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00237: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00369: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00420: reducing learning rate of group 0 to 1.0000e-04.
# 69 Meat
# {'accuracy': 0.8,
#  'duration': 62.583436727523804,
#  'f1': 0.797175866495507,
#  'loss': 0.7444158792495728,
#  'precision': 0.7962962962962963,
#  'recall': 0.7999999999999999}
# Epoch 00062: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00113: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00164: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00215: reducing learning rate of group 0 to 1.0000e-04.
# 71 MelbournePedestrian
# {'accuracy': 0.998324958123953,
#  'duration': 1100.9991791248322,
#  'f1': 0.9983115609342745,
#  'loss': 1.462848054735284,
#  'precision': 0.998340220385675,
#  'recall': 0.9982971014492754}
# Epoch 00120: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00171: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00222: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00273: reducing learning rate of group 0 to 1.0000e-04.
# 73 MiddlePhalanxOutlineCorrect
# {'accuracy': 0.8016666666666666,
#  'duration': 537.0463721752167,
#  'f1': 0.7678494207615449,
#  'loss': 0.5067319959402085,
#  'precision': 0.7987207461600994,
#  'recall': 0.7546440381248785}
# Epoch 00070: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00192: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00243: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00294: reducing learning rate of group 0 to 1.0000e-04.
# 75 MixedShapesRegularTrain
# {'accuracy': 0.996,
#  'duration': 2043.9991428852081,
#  'f1': 0.9959995999599961,
#  'loss': 0.9086783453822136,
#  'precision': 0.996078431372549,
#  'recall': 0.9960000000000001}
# Epoch 00083: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00134: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00185: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00236: reducing learning rate of group 0 to 1.0000e-04.
# 77 MoteStrain
# {'accuracy': 1.0,
#  'duration': 343.46419167518616,
#  'f1': 1.0,
#  'loss': 0.3132883906364441,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00385: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00642: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00739: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00790: reducing learning rate of group 0 to 1.0000e-04.
# 79 NonInvasiveFetalECGThorax2
# {'accuracy': 0.805,
#  'duration': 2645.163809299469,
#  'f1': 0.7316397018664347,
#  'loss': 2.975643856772061,
#  'precision': 0.6938673875530905,
#  'recall': 0.7924096736122638}
# Epoch 00142: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00216: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00297: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00348: reducing learning rate of group 0 to 1.0000e-04.
# 81 OliveOil
# {'accuracy': 0.5666666666666667,
#  'duration': 54.79744625091553,
#  'f1': 0.4246408240715641,
#  'loss': 1.162959337234497,
#  'precision': 0.41666666666666663,
#  'recall': 0.4495192307692308}
# Epoch 00190: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00267: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00412: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00463: reducing learning rate of group 0 to 1.0000e-04.
# 83 PhalangesOutlinesCorrect
# {'accuracy': 0.7722222222222223,
#  'duration': 1588.4693908691406,
#  'f1': 0.7288359788359788,
#  'loss': 0.5256622556982369,
#  'precision': 0.7618956960163861,
#  'recall': 0.7168050694550119}
# Epoch 00255: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00306: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00391: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00442: reducing learning rate of group 0 to 1.0000e-04.
# 85 PickupGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 55.80476140975952,
#  'f1': 1.0,
#  'loss': 1.4614250659942627,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00333: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00419: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00516: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00567: reducing learning rate of group 0 to 1.0000e-04.
# 87 PigArtPressure
# {'accuracy': 1.0,
#  'duration': 455.7268879413605,
#  'f1': 1.0,
#  'loss': 2.9840816259384155,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00132: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00311: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00420: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00471: reducing learning rate of group 0 to 1.0000e-04.
# 89 Plane
# {'accuracy': 1.0,
#  'duration': 271.7289035320282,
#  'f1': 1.0,
#  'loss': 1.1655519604682922,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00061: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00112: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00163: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00263: reducing learning rate of group 0 to 1.0000e-04.
# 91 ProximalPhalanxOutlineAgeGroup
# {'accuracy': 0.83,
#  'duration': 382.636421918869,
#  'f1': 0.7996485854554131,
#  'loss': 0.7231436967849731,
#  'precision': 0.8217547438811241,
#  'recall': 0.7919045715808305}
# Epoch 00199: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00330: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00381: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00432: reducing learning rate of group 0 to 1.0000e-04.
# 93 ProximalPhalanxTW
# {'accuracy': 0.7875,
#  'duration': 382.90316700935364,
#  'f1': 0.38856663574808353,
#  'loss': 1.2704311438969202,
#  'precision': 0.3610181014995428,
#  'recall': 0.42283560054834973}
# Epoch 00101: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00152: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00203: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00254: reducing learning rate of group 0 to 1.0000e-04.
# 95 Rock
# {'accuracy': 1.0,
#  'duration': 147.0735650062561,
#  'f1': 1.0,
#  'loss': 0.7440520524978638,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00154: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.0000e-04.
# 97 SemgHandGenderCh2
# {'accuracy': 1.0,
#  'duration': 1003.9037020206451,
#  'f1': 1.0,
#  'loss': 0.3134078621864319,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00293: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00344: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00581: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00632: reducing learning rate of group 0 to 1.0000e-04.
# 99 SemgHandSubjectCh2
# {'accuracy': 0.98,
#  'duration': 1159.3945753574371,
#  'f1': 0.9799597809483028,
#  'loss': 0.9949672222137451,
#  'precision': 0.9801132400832551,
#  'recall': 0.9800000000000001}
# Epoch 00059: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00110: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00161: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.0000e-04.
# 101 ShapeletSim
# {'accuracy': 1.0,
#  'duration': 102.81578254699707,
#  'f1': 1.0,
#  'loss': 0.3133189082145691,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00060: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00161: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00263: reducing learning rate of group 0 to 1.0000e-04.
# 103 SmallKitchenAppliances
# {'accuracy': 0.952,
#  'duration': 517.7578160762787,
#  'f1': 0.9521810370756102,
#  'loss': 0.6006569564342499,
#  'precision': 0.9548587885544407,
#  'recall': 0.952}
# Epoch 00054: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00105: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00156: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00207: reducing learning rate of group 0 to 1.0000e-04.
# 105 SonyAIBORobotSurface1
# {'accuracy': 1.0,
#  'duration': 192.88242864608765,
#  'f1': 1.0,
#  'loss': 0.3133343756198883,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00279: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00330: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00381: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00432: reducing learning rate of group 0 to 1.0000e-04.
# 107 StarLightCurves
# {'accuracy': 0.992,
#  'duration': 6132.559739589691,
#  'f1': 0.9887366393238878,
#  'loss': 0.5606355890631676,
#  'precision': 0.9936869583047452,
#  'recall': 0.9840673892409907}
# Epoch 00166: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00244: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00356: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00451: reducing learning rate of group 0 to 1.0000e-04.
# 109 SwedishLeaf
# {'accuracy': 0.982,
#  'duration': 1201.5078873634338,
#  'f1': 0.9814881234637592,
#  'loss': 1.8344878256320953,
#  'precision': 0.9818307470031608,
#  'recall': 0.9818380852863612}
# Epoch 00182: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00233: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00284: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00335: reducing learning rate of group 0 to 1.0000e-04.
# 111 SyntheticControl
# {'accuracy': 1.0,
#  'duration': 320.40314388275146,
#  'f1': 1.0,
#  'loss': 1.0436506986618042,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00056: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00107: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00158: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.0000e-04.
# 113 ToeSegmentation2
# {'accuracy': 1.0,
#  'duration': 93.468989610672,
#  'f1': 1.0,
#  'loss': 0.3132947087287903,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00117: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00168: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00219: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00270: reducing learning rate of group 0 to 1.0000e-04.
# 115 TwoLeadECG
# {'accuracy': 1.0,
#  'duration': 332.5177276134491,
#  'f1': 1.0,
#  'loss': 0.31365975737571716,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00152: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00228: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00279: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00330: reducing learning rate of group 0 to 1.0000e-04.
# 117 UMD
# {'accuracy': 1.0,
#  'duration': 151.25359630584717,
#  'f1': 1.0,
#  'loss': 0.5517701506614685,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00177: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00234: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00285: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00336: reducing learning rate of group 0 to 1.0000e-04.
# 119 UWaveGestureLibraryX
# {'accuracy': 0.9910714285714286,
#  'duration': 1635.2752032279968,
#  'f1': 0.9912519269936035,
#  'loss': 1.2833445157323564,
#  'precision': 0.9911739217460436,
#  'recall': 0.9914164306511748}
# Epoch 00051: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00102: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00153: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00204: reducing learning rate of group 0 to 1.0000e-04.
# 121 UWaveGestureLibraryZ
# {'accuracy': 0.9854910714285714,
#  'duration': 1585.1077373027802,
#  'f1': 0.985477843563094,
#  'loss': 1.289958689893995,
#  'precision': 0.9855660373828978,
#  'recall': 0.9854320165988895}
# Epoch 00107: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00158: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00279: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00355: reducing learning rate of group 0 to 1.0000e-04.
# 123 Wine
# {'accuracy': 0.6842105263157895,
#  'duration': 60.76218843460083,
#  'f1': 0.6607142857142857,
#  'loss': 0.6557095050811768,
#  'precision': 0.7214285714285715,
#  'recall': 0.6722222222222223}
# Epoch 00228: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00279: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00335: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00386: reducing learning rate of group 0 to 1.0000e-04.
# 125 Worms
# {'accuracy': 1.0,
#  'duration': 262.4867117404938,
#  'f1': 1.0,
#  'loss': 0.904880702495575,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00184: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00252: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00349: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00400: reducing learning rate of group 0 to 1.0000e-04.
# 127 Yoga
# {'accuracy': 0.9966666666666667,
#  'duration': 1255.3507068157196,
#  'f1': 0.9966433566433566,
#  'loss': 0.32015069723129275,
#  'precision': 0.9963768115942029,
#  'recall': 0.9969325153374233}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
