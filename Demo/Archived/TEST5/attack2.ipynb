# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST5

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try6_c_Classfier

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
trainer = Trainer(model=model_class)

for i, i_dataset in enumerate(part_DATASETs):
    attacker = attack_model(
        train_method_path=trainer.method_path,
        dataset=i_dataset,
        model=model_class,
    )
    _ = os.path.dirname(attacker.model_weight_path)
    # check if csv file esists
    while not os.path.exists(os.path.join(_, "test_metrics.csv")):
        time.sleep(1)
    attacker.perturb_all(
        to_device=True,
        override=True,
    )
    print(i, i_dataset)
    pprint(attacker.data)
    print("\n")
# Out:
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 0 ACSF1
# {'ASR': 0.58,
#  'Count_Fail': 42,
#  'Count_Success': 58,
#  'duration': 161.78555488586426,
#  'mean_failure_distance': 10.426996,
#  'mean_success_distance': 9.011735,
#  'overall_mean_distance': 9.606144}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 1 Adiac
# {'ASR': 0.8337595907928389,
#  'Count_Fail': 65,
#  'Count_Success': 326,
#  'duration': 831.0597033500671,
#  'mean_failure_distance': 1.15399,
#  'mean_success_distance': 1.0324409,
#  'overall_mean_distance': 1.0526472}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 2 AllGestureWiimoteX
# {'ASR': 0.7914285714285715,
#  'Count_Fail': 146,
#  'Count_Success': 554,
#  'duration': 612.2943556308746,
#  'mean_failure_distance': 2.5023258,
#  'mean_success_distance': 1.9258308,
#  'overall_mean_distance': 2.0460713}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 3 AllGestureWiimoteY
# {'ASR': 0.8171428571428572,
#  'Count_Fail': 128,
#  'Count_Success': 572,
#  'duration': 601.6791427135468,
#  'mean_failure_distance': 1.7607014,
#  'mean_success_distance': 1.70626,
#  'overall_mean_distance': 1.7162149}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 4 AllGestureWiimoteZ
# {'ASR': 0.7571428571428571,
#  'Count_Fail': 170,
#  'Count_Success': 530,
#  'duration': 601.537403345108,
#  'mean_failure_distance': 3.0867321,
#  'mean_success_distance': 3.3112457,
#  'overall_mean_distance': 3.2567208}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 5 ArrowHead
# {'ASR': 0.5371428571428571,
#  'Count_Fail': 81,
#  'Count_Success': 94,
#  'duration': 159.80178999900818,
#  'mean_failure_distance': 2.2036827,
#  'mean_success_distance': 2.2460852,
#  'overall_mean_distance': 2.226459}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 6 BME
# {'ASR': 0.35333333333333333,
#  'Count_Fail': 97,
#  'Count_Success': 53,
#  'duration': 308.8869614601135,
#  'mean_failure_distance': 1.1781497,
#  'mean_success_distance': 1.1768601,
#  'overall_mean_distance': 1.1776941}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 7 Beef
# {'ASR': 0.6666666666666666,
#  'Count_Fail': 10,
#  'Count_Success': 20,
#  'duration': 53.6139657497406,
#  'mean_failure_distance': 3.9445267,
#  'mean_success_distance': 3.650512,
#  'overall_mean_distance': 3.7485168}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 8 BeetleFly
# {'ASR': 0.35,
#  'Count_Fail': 13,
#  'Count_Success': 7,
#  'duration': 53.50158095359802,
#  'mean_failure_distance': 5.008958,
#  'mean_success_distance': 4.999105,
#  'overall_mean_distance': 5.0055094}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 9 BirdChicken
# {'ASR': 0.3,
#  'Count_Fail': 14,
#  'Count_Success': 6,
#  'duration': 52.632142066955566,
#  'mean_failure_distance': 4.962465,
#  'mean_success_distance': 4.8605638,
#  'overall_mean_distance': 4.9318943}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 10 CBF
# {'ASR': 0.05444444444444444,
#  'Count_Fail': 851,
#  'Count_Success': 49,
#  'duration': 1855.4599833488464,
#  'mean_failure_distance': 1.2147783,
#  'mean_success_distance': 1.2002875,
#  'overall_mean_distance': 1.2139894}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 11 Car
# {'ASR': 0.55,
#  'Count_Fail': 27,
#  'Count_Success': 33,
#  'duration': 52.53904151916504,
#  'mean_failure_distance': 5.3913555,
#  'mean_success_distance': 5.0611687,
#  'overall_mean_distance': 5.209753}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/conda/Anaconda3/envs/pytorch_gpu/lib/python3.11/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# 12 Chinatown
# {'ASR': 0.0,
#  'Count_Fail': 343,
#  'Count_Success': 0,
#  'duration': 311.37148427963257,
#  'mean_failure_distance': 0.0840185,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.0840185}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 13 ChlorineConcentration
# {'ASR': 0.8708333333333333,
#  'Count_Fail': 496,
#  'Count_Success': 3344,
#  'duration': 7821.644577503204,
#  'mean_failure_distance': 1.027604,
#  'mean_success_distance': 1.3151569,
#  'overall_mean_distance': 1.2780147}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 14 CinCECGTorso
# {'ASR': 0.7818840579710145,
#  'Count_Fail': 301,
#  'Count_Success': 1079,
#  'duration': 2451.274089574814,
#  'mean_failure_distance': 12.551122,
#  'mean_success_distance': 13.0253315,
#  'overall_mean_distance': 12.921898}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 15 Coffee
# {'ASR': 0.9642857142857143,
#  'Count_Fail': 1,
#  'Count_Success': 27,
#  'duration': 52.30600023269653,
#  'mean_failure_distance': 0.31781164,
#  'mean_success_distance': 2.5014694,
#  'overall_mean_distance': 2.4234815}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 16 Computers
# {'ASR': 0.76,
#  'Count_Fail': 60,
#  'Count_Success': 190,
#  'duration': 222.41570782661438,
#  'mean_failure_distance': 4.8193364,
#  'mean_success_distance': 5.4095225,
#  'overall_mean_distance': 5.2678785}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 17 CricketX
# {'ASR': 0.258974358974359,
#  'Count_Fail': 289,
#  'Count_Success': 101,
#  'duration': 379.5977511405945,
#  'mean_failure_distance': 2.2518117,
#  'mean_success_distance': 2.489352,
#  'overall_mean_distance': 2.3133285}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 18 CricketY
# {'ASR': 0.358974358974359,
#  'Count_Fail': 250,
#  'Count_Success': 140,
#  'duration': 369.6165134906769,
#  'mean_failure_distance': 2.3693128,
#  'mean_success_distance': 2.3798506,
#  'overall_mean_distance': 2.3730955}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 19 CricketZ
# {'ASR': 0.30512820512820515,
#  'Count_Fail': 271,
#  'Count_Success': 119,
#  'duration': 380.0508408546448,
#  'mean_failure_distance': 2.4089913,
#  'mean_success_distance': 2.5160787,
#  'overall_mean_distance': 2.4416666}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 20 Crop
# {'ASR': 0.8725595238095238,
#  'Count_Fail': 2141,
#  'Count_Success': 14659,
#  'duration': 14313.26257610321,
#  'mean_failure_distance': 0.07608628,
#  'mean_success_distance': 0.1088853,
#  'overall_mean_distance': 0.10470538}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 21 DiatomSizeReduction
# {'ASR': 0.545751633986928,
#  'Count_Fail': 139,
#  'Count_Success': 167,
#  'duration': 279.6006760597229,
#  'mean_failure_distance': 3.1197338,
#  'mean_success_distance': 3.1340408,
#  'overall_mean_distance': 3.127542}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 22 DistalPhalanxOutlineAgeGroup
# {'ASR': 0.28776978417266186,
#  'Count_Fail': 99,
#  'Count_Success': 40,
#  'duration': 164.01650094985962,
#  'mean_failure_distance': 0.5652107,
#  'mean_success_distance': 0.6696599,
#  'overall_mean_distance': 0.59526795}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 23 DistalPhalanxOutlineCorrect
# {'ASR': 0.7137681159420289,
#  'Count_Fail': 79,
#  'Count_Success': 197,
#  'duration': 267.0347406864166,
#  'mean_failure_distance': 0.65131193,
#  'mean_success_distance': 0.70571405,
#  'overall_mean_distance': 0.69014245}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 24 DistalPhalanxTW
# {'ASR': 0.4316546762589928,
#  'Count_Fail': 79,
#  'Count_Success': 60,
#  'duration': 164.5249526500702,
#  'mean_failure_distance': 0.65986806,
#  'mean_success_distance': 0.564819,
#  'overall_mean_distance': 0.6188397}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 25 DodgerLoopDay
# {'ASR': 0.1,
#  'Count_Fail': 72,
#  'Count_Success': 8,
#  'duration': 110.06081318855286,
#  'mean_failure_distance': 2.641942,
#  'mean_success_distance': 2.6724174,
#  'overall_mean_distance': 2.6449897}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 26 DodgerLoopGame
# {'ASR': 0.014492753623188406,
#  'Count_Fail': 136,
#  'Count_Success': 2,
#  'duration': 167.0202989578247,
#  'mean_failure_distance': 2.4280381,
#  'mean_success_distance': 2.8518791,
#  'overall_mean_distance': 2.4341812}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 27 DodgerLoopWeekend
# {'ASR': 0.0,
#  'Count_Fail': 138,
#  'Count_Success': 0,
#  'duration': 166.29484105110168,
#  'mean_failure_distance': 1.7003055,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 1.7003055}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 28 ECG200
# {'ASR': 0.17,
#  'Count_Fail': 83,
#  'Count_Success': 17,
#  'duration': 221.55675530433655,
#  'mean_failure_distance': 0.89602625,
#  'mean_success_distance': 0.9193631,
#  'overall_mean_distance': 0.8999934}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 29 ECG5000
# {'ASR': 0.08311111111111111,
#  'Count_Fail': 4126,
#  'Count_Success': 374,
#  'duration': 9156.761407375336,
#  'mean_failure_distance': 0.44996065,
#  'mean_success_distance': 1.1721518,
#  'overall_mean_distance': 0.5099828}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 30 ECGFiveDays
# {'ASR': 0.5261324041811847,
#  'Count_Fail': 408,
#  'Count_Success': 453,
#  'duration': 1782.4150664806366,
#  'mean_failure_distance': 1.3159301,
#  'mean_success_distance': 1.2948546,
#  'overall_mean_distance': 1.3048416}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 31 EOGHorizontalSignal
# {'ASR': 0.011049723756906077,
#  'Count_Fail': 358,
#  'Count_Success': 4,
#  'duration': 505.41012835502625,
#  'mean_failure_distance': 7.171658,
#  'mean_success_distance': 6.440069,
#  'overall_mean_distance': 7.163574}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 32 EOGVerticalSignal
# {'ASR': 0.022099447513812154,
#  'Count_Fail': 354,
#  'Count_Success': 8,
#  'duration': 505.45106387138367,
#  'mean_failure_distance': 8.863191,
#  'mean_success_distance': 10.837949,
#  'overall_mean_distance': 8.906832}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 33 Earthquakes
# {'ASR': 0.8633093525179856,
#  'Count_Fail': 19,
#  'Count_Success': 120,
#  'duration': 172.93853902816772,
#  'mean_failure_distance': 1.8149252,
#  'mean_success_distance': 3.4881005,
#  'overall_mean_distance': 3.259393}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 34 ElectricDevices
# {'ASR': 0.3583192841395409,
#  'Count_Fail': 4948,
#  'Count_Success': 2763,
#  'duration': 15425.369796037674,
#  'mean_failure_distance': 0.3853378,
#  'mean_success_distance': 0.5745524,
#  'overall_mean_distance': 0.45313704}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 35 EthanolLevel
# {'ASR': 0.834,
#  'Count_Fail': 83,
#  'Count_Success': 417,
#  'duration': 933.1555025577545,
#  'mean_failure_distance': 7.0805044,
#  'mean_success_distance': 10.093282,
#  'overall_mean_distance': 9.593161}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 36 FaceAll
# {'ASR': 0.2644970414201183,
#  'Count_Fail': 1243,
#  'Count_Success': 447,
#  'duration': 3444.4029915332794,
#  'mean_failure_distance': 0.5417638,
#  'mean_success_distance': 1.0680628,
#  'overall_mean_distance': 0.68096834}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 37 FaceFour
# {'ASR': 0.23863636363636365,
#  'Count_Fail': 67,
#  'Count_Success': 21,
#  'duration': 112.61968874931335,
#  'mean_failure_distance': 3.3910522,
#  'mean_success_distance': 3.418154,
#  'overall_mean_distance': 3.3975196}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 38 FacesUCR
# {'ASR': 0.24292682926829268,
#  'Count_Fail': 1552,
#  'Count_Success': 498,
#  'duration': 4206.757639408112,
#  'mean_failure_distance': 1.0841385,
#  'mean_success_distance': 1.1237066,
#  'overall_mean_distance': 1.0937507}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 39 FiftyWords
# {'ASR': 0.2681318681318681,
#  'Count_Fail': 333,
#  'Count_Success': 122,
#  'duration': 456.3157513141632,
#  'mean_failure_distance': 2.1757452,
#  'mean_success_distance': 2.2231364,
#  'overall_mean_distance': 2.1884525}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 40 Fish
# {'ASR': 0.6571428571428571,
#  'Count_Fail': 60,
#  'Count_Success': 115,
#  'duration': 176.5594606399536,
#  'mean_failure_distance': 3.744827,
#  'mean_success_distance': 3.8138773,
#  'overall_mean_distance': 3.790203}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 41 FordA
# {'ASR': 0.32196969696969696,
#  'Count_Fail': 895,
#  'Count_Success': 425,
#  'duration': 1256.1939969062805,
#  'mean_failure_distance': 0.5048048,
#  'mean_success_distance': 3.9687834,
#  'overall_mean_distance': 1.6201009}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 42 FordB
# {'ASR': 0.4962962962962963,
#  'Count_Fail': 408,
#  'Count_Success': 402,
#  'duration': 773.6947197914124,
#  'mean_failure_distance': 0.969103,
#  'mean_success_distance': 3.8472304,
#  'overall_mean_distance': 2.397507}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 43 FreezerRegularTrain
# {'ASR': 0.68,
#  'Count_Fail': 912,
#  'Count_Success': 1938,
#  'duration': 2615.119771718979,
#  'mean_failure_distance': 2.5043488,
#  'mean_success_distance': 2.7784932,
#  'overall_mean_distance': 2.6907668}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 44 FreezerSmallTrain
# {'ASR': 0.32280701754385965,
#  'Count_Fail': 1930,
#  'Count_Success': 920,
#  'duration': 2617.372076511383,
#  'mean_failure_distance': 2.8092642,
#  'mean_success_distance': 2.825708,
#  'overall_mean_distance': 2.8145723}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 45 Fungi
# {'ASR': 0.021505376344086023,
#  'Count_Fail': 182,
#  'Count_Success': 4,
#  'duration': 392.8348112106323,
#  'mean_failure_distance': 1.5113137,
#  'mean_success_distance': 1.9594865,
#  'overall_mean_distance': 1.5209517}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 46 GestureMidAirD1
# {'ASR': 0.03076923076923077,
#  'Count_Fail': 126,
#  'Count_Success': 4,
#  'duration': 173.85769391059875,
#  'mean_failure_distance': 2.5031853,
#  'mean_success_distance': 2.9549236,
#  'overall_mean_distance': 2.5170846}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 47 GestureMidAirD2
# {'ASR': 0.007692307692307693,
#  'Count_Fail': 129,
#  'Count_Success': 1,
#  'duration': 173.33721280097961,
#  'mean_failure_distance': 1.757039,
#  'mean_success_distance': 1.8315792,
#  'overall_mean_distance': 1.7576123}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 48 GestureMidAirD3
# {'ASR': 0.16923076923076924,
#  'Count_Fail': 108,
#  'Count_Success': 22,
#  'duration': 173.88502550125122,
#  'mean_failure_distance': 3.2221026,
#  'mean_success_distance': 3.240161,
#  'overall_mean_distance': 3.2251587}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 49 GesturePebbleZ1
# {'ASR': 0.011627906976744186,
#  'Count_Fail': 170,
#  'Count_Success': 2,
#  'duration': 179.54389452934265,
#  'mean_failure_distance': 3.5582156,
#  'mean_success_distance': 4.145026,
#  'overall_mean_distance': 3.565039}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 50 GesturePebbleZ2
# {'ASR': 0.0189873417721519,
#  'Count_Fail': 155,
#  'Count_Success': 3,
#  'duration': 179.7868993282318,
#  'mean_failure_distance': 3.3849578,
#  'mean_success_distance': 4.417871,
#  'overall_mean_distance': 3.4045696}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 51 GunPoint
# {'ASR': 0.49333333333333335,
#  'Count_Fail': 76,
#  'Count_Success': 74,
#  'duration': 321.498085975647,
#  'mean_failure_distance': 1.3935149,
#  'mean_success_distance': 1.3384398,
#  'overall_mean_distance': 1.3663445}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 52 GunPointAgeSpan
# {'ASR': 0.0031645569620253164,
#  'Count_Fail': 315,
#  'Count_Success': 1,
#  'duration': 654.5256948471069,
#  'mean_failure_distance': 0.34834874,
#  'mean_success_distance': 1.5000551,
#  'overall_mean_distance': 0.35199338}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 53 GunPointMaleVersusFemale
# {'ASR': 0.0,
#  'Count_Fail': 316,
#  'Count_Success': 0,
#  'duration': 653.5147755146027,
#  'mean_failure_distance': 0.19136938,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.19136938}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 54 GunPointOldVersusYoung
# {'ASR': 0.0,
#  'Count_Fail': 315,
#  'Count_Success': 0,
#  'duration': 652.7584846019745,
#  'mean_failure_distance': 0.020900143,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 0.020900143}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 55 Ham
# {'ASR': 0.7523809523809524,
#  'Count_Fail': 26,
#  'Count_Success': 79,
#  'duration': 120.49300718307495,
#  'mean_failure_distance': 2.7841754,
#  'mean_success_distance': 3.5375211,
#  'overall_mean_distance': 3.350978}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 56 HandOutlines
# {'ASR': 0.8972972972972973,
#  'Count_Fail': 38,
#  'Count_Success': 332,
#  'duration': 1034.3963532447815,
#  'mean_failure_distance': 4.4720387,
#  'mean_success_distance': 12.933453,
#  'overall_mean_distance': 12.064443}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 57 Haptics
# {'ASR': 0.8084415584415584,
#  'Count_Fail': 59,
#  'Count_Success': 249,
#  'duration': 383.2725987434387,
#  'mean_failure_distance': 8.447899,
#  'mean_success_distance': 8.914874,
#  'overall_mean_distance': 8.82542}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 58 Herring
# {'ASR': 0.75,
#  'Count_Fail': 16,
#  'Count_Success': 48,
#  'duration': 58.16090488433838,
#  'mean_failure_distance': 2.7127013,
#  'mean_success_distance': 3.559391,
#  'overall_mean_distance': 3.3477187}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 59 HouseTwenty
# {'ASR': 0.0,
#  'Count_Fail': 119,
#  'Count_Success': 0,
#  'duration': 251.45000219345093,
#  'mean_failure_distance': 6.6913137,
#  'mean_success_distance': nan,
#  'overall_mean_distance': 6.6913137}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 60 InlineSkate
# {'ASR': 0.7745454545454545,
#  'Count_Fail': 124,
#  'Count_Success': 426,
#  'duration': 1103.2838151454926,
#  'mean_failure_distance': 14.886118,
#  'mean_success_distance': 15.230833,
#  'overall_mean_distance': 15.153114}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 61 InsectEPGRegularTrain
# {'ASR': 0.11646586345381527,
#  'Count_Fail': 220,
#  'Count_Success': 29,
#  'duration': 248.00967931747437,
#  'mean_failure_distance': 0.13376902,
#  'mean_success_distance': 2.8125112,
#  'overall_mean_distance': 0.445751}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 62 InsectEPGSmallTrain
# {'ASR': 0.13253012048192772,
#  'Count_Fail': 216,
#  'Count_Success': 33,
#  'duration': 248.05155444145203,
#  'mean_failure_distance': 0.2914514,
#  'mean_success_distance': 2.108631,
#  'overall_mean_distance': 0.5322825}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 63 InsectWingbeatSound
# {'ASR': 0.4707070707070707,
#  'Count_Fail': 1048,
#  'Count_Success': 932,
#  'duration': 1856.2478308677673,
#  'mean_failure_distance': 2.0675733,
#  'mean_success_distance': 1.9455627,
#  'overall_mean_distance': 2.010142}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 64 ItalyPowerDemand
# {'ASR': 0.27793974732750243,
#  'Count_Fail': 743,
#  'Count_Success': 286,
#  'duration': 980.5691175460815,
#  'mean_failure_distance': 0.2363564,
#  'mean_success_distance': 0.23853235,
#  'overall_mean_distance': 0.23696119}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 65 LargeKitchenAppliances
# {'ASR': 0.648,
#  'Count_Fail': 132,
#  'Count_Success': 243,
#  'duration': 367.92194533348083,
#  'mean_failure_distance': 2.4783745,
#  'mean_success_distance': 4.1982555,
#  'overall_mean_distance': 3.5928574}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 66 Lightning2
# {'ASR': 0.47540983606557374,
#  'Count_Fail': 32,
#  'Count_Success': 29,
#  'duration': 62.10095810890198,
#  'mean_failure_distance': 6.0484977,
#  'mean_success_distance': 5.6968784,
#  'overall_mean_distance': 5.8813343}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 67 Lightning7
# {'ASR': 0.2465753424657534,
#  'Count_Fail': 55,
#  'Count_Success': 18,
#  'duration': 120.08593153953552,
#  'mean_failure_distance': 2.8891923,
#  'mean_success_distance': 2.6425993,
#  'overall_mean_distance': 2.8283887}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 68 Mallat
# {'ASR': 0.5236673773987207,
#  'Count_Fail': 1117,
#  'Count_Success': 1228,
#  'duration': 2711.6817059516907,
#  'mean_failure_distance': 9.148632,
#  'mean_success_distance': 8.984849,
#  'overall_mean_distance': 9.062863}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 69 Meat
# {'ASR': 0.8,
#  'Count_Fail': 12,
#  'Count_Success': 48,
#  'duration': 63.33293890953064,
#  'mean_failure_distance': 0.85074633,
#  'mean_success_distance': 1.3782247,
#  'overall_mean_distance': 1.272729}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 70 MedicalImages
# {'ASR': 0.3907894736842105,
#  'Count_Fail': 463,
#  'Count_Success': 297,
#  'duration': 1559.7020785808563,
#  'mean_failure_distance': 0.75439376,
#  'mean_success_distance': 0.7101602,
#  'overall_mean_distance': 0.7371077}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 71 MelbournePedestrian
# {'ASR': 0.0012300123001230013,
#  'Count_Fail': 2436,
#  'Count_Success': 3,
#  'duration': 2260.690487384796,
#  'mean_failure_distance': 0.02895153,
#  'mean_success_distance': 0.23067145,
#  'overall_mean_distance': 0.029199649}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 72 MiddlePhalanxOutlineAgeGroup
# {'ASR': 0.6428571428571429,
#  'Count_Fail': 55,
#  'Count_Success': 99,
#  'duration': 181.21570491790771,
#  'mean_failure_distance': 0.62785226,
#  'mean_success_distance': 0.66497004,
#  'overall_mean_distance': 0.65171367}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 73 MiddlePhalanxOutlineCorrect
# {'ASR': 0.7010309278350515,
#  'Count_Fail': 87,
#  'Count_Success': 204,
#  'duration': 293.11989402770996,
#  'mean_failure_distance': 0.68225014,
#  'mean_success_distance': 0.7315936,
#  'overall_mean_distance': 0.7168415}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 74 MiddlePhalanxTW
# {'ASR': 0.525974025974026,
#  'Count_Fail': 73,
#  'Count_Success': 81,
#  'duration': 181.79255938529968,
#  'mean_failure_distance': 0.62958884,
#  'mean_success_distance': 0.60248035,
#  'overall_mean_distance': 0.61533046}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 75 MixedShapesRegularTrain
# {'ASR': 0.3839175257731959,
#  'Count_Fail': 1494,
#  'Count_Success': 931,
#  'duration': 2789.4267003536224,
#  'mean_failure_distance': 4.8938174,
#  'mean_success_distance': 7.6851273,
#  'overall_mean_distance': 5.9654503}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 76 MixedShapesSmallTrain
# {'ASR': 0.2865979381443299,
#  'Count_Fail': 1730,
#  'Count_Success': 695,
#  'duration': 2796.144541501999,
#  'mean_failure_distance': 7.227098,
#  'mean_success_distance': 8.5279455,
#  'overall_mean_distance': 7.599918}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 77 MoteStrain
# {'ASR': 0.21485623003194887,
#  'Count_Fail': 983,
#  'Count_Success': 269,
#  'duration': 1220.6654272079468,
#  'mean_failure_distance': 0.7998968,
#  'mean_success_distance': 0.81308496,
#  'overall_mean_distance': 0.8027304}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 78 NonInvasiveFetalECGThorax1
# {'ASR': 0.7358778625954199,
#  'Count_Fail': 519,
#  'Count_Success': 1446,
#  'duration': 1941.5806744098663,
#  'mean_failure_distance': 1.5328853,
#  'mean_success_distance': 3.247047,
#  'overall_mean_distance': 2.794299}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 79 NonInvasiveFetalECGThorax2
# {'ASR': 0.7653944020356234,
#  'Count_Fail': 461,
#  'Count_Success': 1504,
#  'duration': 1940.2670259475708,
#  'mean_failure_distance': 2.4769242,
#  'mean_success_distance': 3.6807873,
#  'overall_mean_distance': 3.3983545}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 80 OSULeaf
# {'ASR': 0.371900826446281,
#  'Count_Fail': 152,
#  'Count_Success': 90,
#  'duration': 253.17706394195557,
#  'mean_failure_distance': 3.6326134,
#  'mean_success_distance': 3.5623689,
#  'overall_mean_distance': 3.6064894}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 81 OliveOil
# {'ASR': 0.8,
#  'Count_Fail': 6,
#  'Count_Success': 24,
#  'duration': 62.966200828552246,
#  'mean_failure_distance': 0.6741881,
#  'mean_success_distance': 1.2545625,
#  'overall_mean_distance': 1.1384877}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 82 PLAID
# {'ASR': 0.6890130353817505,
#  'Count_Fail': 167,
#  'Count_Success': 370,
#  'duration': 803.9469380378723,
#  'mean_failure_distance': 5.0727577,
#  'mean_success_distance': 2.654571,
#  'overall_mean_distance': 3.4065955}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 83 PhalangesOutlinesCorrect
# {'ASR': 0.6585081585081585,
#  'Count_Fail': 293,
#  'Count_Success': 565,
#  'duration': 855.6456522941589,
#  'mean_failure_distance': 0.6466354,
#  'mean_success_distance': 0.7131689,
#  'overall_mean_distance': 0.69044834}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 84 Phoneme
# {'ASR': 0.515295358649789,
#  'Count_Fail': 919,
#  'Count_Success': 977,
#  'duration': 2207.3277671337128,
#  'mean_failure_distance': 9.398458,
#  'mean_success_distance': 9.200366,
#  'overall_mean_distance': 9.296382}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 85 PickupGestureWiimoteZ
# {'ASR': 0.66,
#  'Count_Fail': 17,
#  'Count_Success': 33,
#  'duration': 63.97237491607666,
#  'mean_failure_distance': 2.9091346,
#  'mean_success_distance': 2.923932,
#  'overall_mean_distance': 2.918901}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 86 PigAirwayPressure
# {'ASR': 0.30288461538461536,
#  'Count_Fail': 145,
#  'Count_Success': 63,
#  'duration': 467.0797085762024,
#  'mean_failure_distance': 17.134806,
#  'mean_success_distance': 16.066832,
#  'overall_mean_distance': 16.811333}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>
# 87 PigArtPressure
# {'ASR': 0.02403846153846154,
#  'Count_Fail': 203,
#  'Count_Success': 5,
#  'duration': 461.10106134414673,
#  'mean_failure_distance': 9.685497,
#  'mean_success_distance': 10.229286,
#  'overall_mean_distance': 9.698568}
#
#
# None
# <class 'CODE.Train.correlated_inception_time.try6_c_Classfier'>

# %%
print(attacker.device)
# Out:
# None

# %%
attacker.model_weight_path
# Out:
# '/homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/OUTPUT/train/model=Classifier_INCEPTION_defence=None/ACSF1/MODEL_INFO.pth'
