# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST5

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try6_c_Classfier

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 1:
        continue
    trainer = Trainer(dataset=i_dataset, epoch=1000, model=model_class)
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00140: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00207: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00429: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00480: reducing learning rate of group 0 to 1.0000e-04.
# 0 ACSF1
# {'accuracy': 0.81,
#  'duration': 251.1474437713623,
#  'f1': 0.7682451970687264,
#  'loss': 1.643215298652649,
#  'precision': 0.771918767507003,
#  'recall': 0.8099999999999999}
# Epoch 00234: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00285: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00336: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00387: reducing learning rate of group 0 to 1.0000e-04.
# 2 AllGestureWiimoteX
# {'accuracy': 1.0,
#  'duration': 446.94951009750366,
#  'f1': 1.0,
#  'loss': 1.4612145662307738,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00228: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00286: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00471: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00522: reducing learning rate of group 0 to 1.0000e-04.
# 4 AllGestureWiimoteZ
# {'accuracy': 0.9966666666666667,
#  'duration': 447.9857234954834,
#  'f1': 0.9966657404834676,
#  'loss': 1.4709076642990113,
#  'precision': 0.9967741935483871,
#  'recall': 0.9966666666666667}
# Epoch 00099: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00150: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00201: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00252: reducing learning rate of group 0 to 1.0000e-04.
# 6 BME
# {'accuracy': 1.0,
#  'duration': 127.99680876731873,
#  'f1': 1.0,
#  'loss': 0.5514903664588928,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00257: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00308: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00359: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00454: reducing learning rate of group 0 to 1.0000e-04.
# 8 BeetleFly
# {'accuracy': 1.0,
#  'duration': 44.20071530342102,
#  'f1': 1.0,
#  'loss': 0.3132938742637634,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00252: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00303: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00354: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00405: reducing learning rate of group 0 to 1.0000e-04.
# 10 CBF
# {'accuracy': 1.0,
#  'duration': 295.11720275878906,
#  'f1': 1.0,
#  'loss': 0.5514782667160034,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00093: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00144: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00195: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00246: reducing learning rate of group 0 to 1.0000e-04.
# 12 Chinatown
# {'accuracy': 1.0,
#  'duration': 101.86038708686829,
#  'f1': 1.0,
#  'loss': 0.31329432129859924,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00345: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00396: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00498: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00549: reducing learning rate of group 0 to 1.0000e-04.
# 14 CinCECGTorso
# {'accuracy': 1.0,
#  'duration': 1278.2911248207092,
#  'f1': 1.0,
#  'loss': 0.7437921762466431,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00154: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.0000e-04.
# 16 Computers
# {'accuracy': 0.996,
#  'duration': 335.6408133506775,
#  'f1': 0.995999935998976,
#  'loss': 0.3191564381122589,
#  'precision': 0.996031746031746,
#  'recall': 0.996}
# Epoch 00176: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00297: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00421: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00472: reducing learning rate of group 0 to 1.0000e-04.
# 18 CricketY
# {'accuracy': 1.0,
#  'duration': 318.98937249183655,
#  'f1': 1.0,
#  'loss': 1.6198623861585344,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00154: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00205: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00256: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00307: reducing learning rate of group 0 to 1.0000e-04.
# 20 Crop
# {'accuracy': 0.76125,
#  'duration': 8605.26280426979,
#  'f1': 0.7587573294031023,
#  'loss': 2.4901442780958867,
#  'precision': 0.7635006361460367,
#  'recall': 0.7612500000000001}
# Epoch 00134: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00185: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00236: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00287: reducing learning rate of group 0 to 1.0000e-04.
# 22 DistalPhalanxOutlineAgeGroup
# {'accuracy': 0.8425,
#  'duration': 339.6818997859955,
#  'f1': 0.7898758539763131,
#  'loss': 0.6892810549054827,
#  'precision': 0.8089924339924339,
#  'recall': 0.7921517088866699}
# Epoch 00154: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00275: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00326: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00407: reducing learning rate of group 0 to 1.0000e-04.
# 24 DistalPhalanxTW
# {'accuracy': 0.81,
#  'duration': 339.6410720348358,
#  'f1': 0.4998414725177976,
#  'loss': 1.2205179589135307,
#  'precision': 0.503431582880901,
#  'recall': 0.5210360847450839}
# Epoch 00071: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00122: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00173: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00224: reducing learning rate of group 0 to 1.0000e-04.
# 26 DodgerLoopGame
# {'accuracy': 1.0,
#  'duration': 75.07747173309326,
#  'f1': 1.0,
#  'loss': 0.31330522894859314,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00084: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00190: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00241: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00314: reducing learning rate of group 0 to 1.0000e-04.
# 28 ECG200
# {'accuracy': 0.99,
#  'duration': 247.70546984672546,
#  'f1': 0.9882061563863663,
#  'loss': 0.32970134913921356,
#  'precision': 0.9928571428571429,
#  'recall': 0.9838709677419355}
# Epoch 00095: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00291: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00342: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00433: reducing learning rate of group 0 to 1.0000e-04.
# 30 ECGFiveDays
# {'accuracy': 1.0,
#  'duration': 227.82890915870667,
#  'f1': 1.0,
#  'loss': 0.3133246898651123,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00140: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00191: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00242: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00293: reducing learning rate of group 0 to 1.0000e-04.
# 32 EOGVerticalSignal
# {'accuracy': 0.9972375690607734,
#  'duration': 773.037918806076,
#  'f1': 0.9972214504028897,
#  'loss': 1.6370904644330342,
#  'precision': 0.9973118279569894,
#  'recall': 0.9972222222222222}
# Epoch 00107: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00410: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00461: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00512: reducing learning rate of group 0 to 1.0000e-04.
# 34 ElectricDevices
# {'accuracy': 0.9492493838225409,
#  'duration': 19402.0191719532,
#  'f1': 0.940161901128817,
#  'loss': 1.2162439167499541,
#  'precision': 0.942627528714105,
#  'recall': 0.9385804084449163}
# Epoch 00279: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00330: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00381: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00432: reducing learning rate of group 0 to 1.0000e-04.
# 36 FaceAll
# {'accuracy': 1.0,
#  'duration': 1558.9932463169098,
#  'f1': 1.0,
#  'loss': 1.754832598898146,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00243: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00380: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00439: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00493: reducing learning rate of group 0 to 1.0000e-04.
# 38 FacesUCR
# {'accuracy': 1.0,
#  'duration': 945.7250573635101,
#  'f1': 1.0,
#  'loss': 1.7559628188610077,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00293: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00344: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00395: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00446: reducing learning rate of group 0 to 1.0000e-04.
# 40 Fish
# {'accuracy': 0.9885714285714285,
#  'duration': 175.95708775520325,
#  'f1': 0.9889783281733747,
#  'loss': 1.1803274552027385,
#  'precision': 0.9895793861311103,
#  'recall': 0.989010989010989}
# Epoch 00101: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00152: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00203: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00254: reducing learning rate of group 0 to 1.0000e-04.
# 42 FordB
# {'accuracy': 0.9980748074807481,
#  'duration': 2681.6411333084106,
#  'f1': 0.9980738037690995,
#  'loss': 0.3151813034425702,
#  'precision': 0.9980676221748037,
#  'recall': 0.998080136588201}
# Epoch 00063: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00165: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00216: reducing learning rate of group 0 to 1.0000e-04.
# 44 FreezerSmallTrain
# {'accuracy': 1.0,
#  'duration': 778.319016456604,
#  'f1': 1.0,
#  'loss': 0.31331494450569153,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00307: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00358: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00409: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00460: reducing learning rate of group 0 to 1.0000e-04.
# 46 GestureMidAirD1
# {'accuracy': 0.9903846153846154,
#  'duration': 175.57220840454102,
#  'f1': 0.9903657616892911,
#  'loss': 2.33264297246933,
#  'precision': 0.9909188034188035,
#  'recall': 0.9903846153846154}
# Epoch 00196: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00256: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00346: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00397: reducing learning rate of group 0 to 1.0000e-04.
# 48 GestureMidAirD3
# {'accuracy': 0.8942307692307693,
#  'duration': 175.62809371948242,
#  'f1': 0.8625833059269592,
#  'loss': 2.4488078355789185,
#  'precision': 0.8409569063415218,
#  'recall': 0.8942307692307693}
# Epoch 00128: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00197: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00248: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00299: reducing learning rate of group 0 to 1.0000e-04.
# 50 GesturePebbleZ2
# {'accuracy': 1.0,
#  'duration': 165.07665634155273,
#  'f1': 1.0,
#  'loss': 1.0439090331395466,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00130: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00216: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00267: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00318: reducing learning rate of group 0 to 1.0000e-04.
# 52 GunPointAgeSpan
# {'accuracy': 0.9777777777777777,
#  'duration': 360.0806953907013,
#  'f1': 0.9777582514141359,
#  'loss': 0.45622270305951435,
#  'precision': 0.9788732394366197,
#  'recall': 0.9776119402985075}
# Epoch 00108: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00159: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00210: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00270: reducing learning rate of group 0 to 1.0000e-04.
# 54 GunPointOldVersusYoung
# {'accuracy': 1.0,
#  'duration': 360.85581398010254,
#  'f1': 1.0,
#  'loss': 0.31344642241795856,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00167: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00218: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00269: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00320: reducing learning rate of group 0 to 1.0000e-04.
# 56 HandOutlines
# {'accuracy': 0.934,
#  'duration': 3330.321148633957,
#  'f1': 0.9273764409174335,
#  'loss': 0.3792179599404335,
#  'precision': 0.9355995410212278,
#  'recall': 0.9207901072065674}
# Epoch 00059: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00110: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00161: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00233: reducing learning rate of group 0 to 1.0000e-04.
# 58 Herring
# {'accuracy': 1.0,
#  'duration': 79.49320483207703,
#  'f1': 1.0,
#  'loss': 0.33284544944763184,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00279: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00396: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00447: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00541: reducing learning rate of group 0 to 1.0000e-04.
# 60 InlineSkate
# {'accuracy': 0.97,
#  'duration': 750.9525945186615,
#  'f1': 0.9703572250156102,
#  'loss': 1.2021333575248718,
#  'precision': 0.9699546485260772,
#  'recall': 0.9716553287981861}
# Epoch 00145: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00196: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00247: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00298: reducing learning rate of group 0 to 1.0000e-04.
# 62 InsectEPGSmallTrain
# {'accuracy': 1.0,
#  'duration': 150.9289529323578,
#  'f1': 1.0,
#  'loss': 0.5515209436416626,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00086: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00184: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00245: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00418: reducing learning rate of group 0 to 1.0000e-04.
# 64 ItalyPowerDemand
# {'accuracy': 0.9850746268656716,
#  'duration': 325.9716377258301,
#  'f1': 0.9850746268656716,
#  'loss': 0.3223915547132492,
#  'precision': 0.9852941176470589,
#  'recall': 0.9852941176470589}
# Epoch 00152: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00203: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00254: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00305: reducing learning rate of group 0 to 1.0000e-04.
# 66 Lightning2
# {'accuracy': 1.0,
#  'duration': 82.08641338348389,
#  'f1': 1.0,
#  'loss': 0.3133313059806824,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00347: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00424: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00475: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00526: reducing learning rate of group 0 to 1.0000e-04.
# 68 Mallat
# {'accuracy': 1.0,
#  'duration': 1453.09539103508,
#  'f1': 1.0,
#  'loss': 1.2742723226547241,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00279: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00430: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00481: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00532: reducing learning rate of group 0 to 1.0000e-04.
# 70 MedicalImages
# {'accuracy': 0.9448818897637795,
#  'duration': 967.2120785713196,
#  'f1': 0.8535725975317119,
#  'loss': 1.5174721082051594,
#  'precision': 0.8557712775088406,
#  'recall': 0.8547040765331619}
# Epoch 00116: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00167: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00218: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00269: reducing learning rate of group 0 to 1.0000e-04.
# 72 MiddlePhalanxOutlineAgeGroup
# {'accuracy': 0.8125,
#  'duration': 395.05684518814087,
#  'f1': 0.7135463864501085,
#  'loss': 0.7297080840383258,
#  'precision': 0.7371562515103185,
#  'recall': 0.7031979428603901}
# Epoch 00085: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00136: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00271: reducing learning rate of group 0 to 1.0000e-04.
# 74 MiddlePhalanxTW
# {'accuracy': 0.6917293233082706,
#  'duration': 396.15862011909485,
#  'f1': 0.4652087022965643,
#  'loss': 1.3597287109919958,
#  'precision': 0.510307400932401,
#  'recall': 0.4720439665054108}
# Epoch 00202: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00317: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00368: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00419: reducing learning rate of group 0 to 1.0000e-04.
# 76 MixedShapesSmallTrain
# {'accuracy': 1.0,
#  'duration': 1556.0283489227295,
#  'f1': 1.0,
#  'loss': 0.9049811363220215,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00555: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00694: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00749: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00800: reducing learning rate of group 0 to 1.0000e-04.
# 78 NonInvasiveFetalECGThorax1
# {'accuracy': 0.8538888888888889,
#  'duration': 2614.232659816742,
#  'f1': 0.8096416066627989,
#  'loss': 2.929585440405484,
#  'precision': 0.7860951789817945,
#  'recall': 0.8486226636207542}
# Epoch 00184: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00296: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00411: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00462: reducing learning rate of group 0 to 1.0000e-04.
# 80 OSULeaf
# {'accuracy': 1.0,
#  'duration': 269.0575797557831,
#  'f1': 1.0,
#  'loss': 1.0455562472343445,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00213: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00301: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00432: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00483: reducing learning rate of group 0 to 1.0000e-04.
# 82 PLAID
# {'accuracy': 0.9236499068901304,
#  'duration': 1203.5981497764587,
#  'f1': 0.7644159723555671,
#  'loss': 1.6207156578699748,
#  'precision': 0.7431491324603214,
#  'recall': 0.7888393504422212}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00118: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00169: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.0000e-04.
# 84 Phoneme
# {'accuracy': 0.8925233644859814,
#  'duration': 1400.6965103149414,
#  'f1': 0.6670774798016951,
#  'loss': 2.8182079195976257,
#  'precision': 0.6401863781174126,
#  'recall': 0.7055444555444556}
# Epoch 00296: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00347: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00398: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00449: reducing learning rate of group 0 to 1.0000e-04.
# 86 PigAirwayPressure
# {'accuracy': 0.8076923076923077,
#  'duration': 449.52464270591736,
#  'f1': 0.7397435897435898,
#  'loss': 3.1753499507904053,
#  'precision': 0.7051282051282051,
#  'recall': 0.8076923076923077}
# Epoch 00323: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00487: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00617: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00670: reducing learning rate of group 0 to 1.0000e-04.
# 88 PigCVP
# {'accuracy': 1.0,
#  'duration': 449.7403829097748,
#  'f1': 1.0,
#  'loss': 2.9848958253860474,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00160: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00274: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00325: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00376: reducing learning rate of group 0 to 1.0000e-04.
# 90 PowerCons
# {'accuracy': 1.0,
#  'duration': 442.6726040840149,
#  'f1': 1.0,
#  'loss': 0.31326860189437866,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00118: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00169: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00348: reducing learning rate of group 0 to 1.0000e-04.
# 92 ProximalPhalanxOutlineCorrect
# {'accuracy': 0.7816666666666666,
#  'duration': 588.7036547660828,
#  'f1': 0.7267408105298656,
#  'loss': 0.5143679171800614,
#  'precision': 0.763451624599959,
#  'recall': 0.7121654562998323}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00154: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.0000e-04.
# 94 RefrigerationDevices
# {'accuracy': 1.0,
#  'duration': 506.17890644073486,
#  'f1': 1.0,
#  'loss': 0.5516357024510702,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00054: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00105: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00156: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00207: reducing learning rate of group 0 to 1.0000e-04.
# 96 ScreenType
# {'accuracy': 0.9893333333333333,
#  'duration': 511.22897267341614,
#  'f1': 0.9893333333333333,
#  'loss': 0.5637392004330953,
#  'precision': 0.9893333333333333,
#  'recall': 0.9893333333333333}
# Epoch 00121: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00324: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00437: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00515: reducing learning rate of group 0 to 1.0000e-04.
# 98 SemgHandMovementCh2
# {'accuracy': 0.9222222222222223,
#  'duration': 1161.441433429718,
#  'f1': 0.9212774704817631,
#  'loss': 1.2108519971370697,
#  'precision': 0.926200153010445,
#  'recall': 0.9222222222222222}
# Epoch 00240: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00335: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00386: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00437: reducing learning rate of group 0 to 1.0000e-04.
# 100 ShakeGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 75.27639174461365,
#  'f1': 1.0,
#  'loss': 1.4613032341003418,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00320: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00583: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00662: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00713: reducing learning rate of group 0 to 1.0000e-04.
# 102 ShapesAll
# {'accuracy': 0.9766666666666667,
#  'duration': 720.8163139820099,
#  'f1': 0.9693553713004515,
#  'loss': 3.1509159088134764,
#  'precision': 0.9640248640248641,
#  'recall': 0.9766666666666667}
# Epoch 00107: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00158: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00260: reducing learning rate of group 0 to 1.0000e-04.
# 104 SmoothSubspace
# {'accuracy': 0.9666666666666667,
#  'duration': 174.3930139541626,
#  'f1': 0.9665252767773777,
#  'loss': 0.5805701017379761,
#  'precision': 0.9669017094017094,
#  'recall': 0.9666666666666667}
# Epoch 00066: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00117: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00168: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00219: reducing learning rate of group 0 to 1.0000e-04.
# 106 SonyAIBORobotSurface2
# {'accuracy': 1.0,
#  'duration': 280.66743564605713,
#  'f1': 1.0,
#  'loss': 0.3133157193660736,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00071: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00149: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00235: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00286: reducing learning rate of group 0 to 1.0000e-04.
# 108 Strawberry
# {'accuracy': 0.9070146818923328,
#  'duration': 567.6715402603149,
#  'f1': 0.9003976568178903,
#  'loss': 0.4029498666524887,
#  'precision': 0.8950849705525334,
#  'recall': 0.9073835848225669}
# Epoch 00139: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00241: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00292: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00417: reducing learning rate of group 0 to 1.0000e-04.
# 110 Symbols
# {'accuracy': 1.0,
#  'duration': 364.872731924057,
#  'f1': 1.0,
#  'loss': 1.0437195301055908,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00062: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00113: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00164: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00215: reducing learning rate of group 0 to 1.0000e-04.
# 112 ToeSegmentation1
# {'accuracy': 1.0,
#  'duration': 126.23543667793274,
#  'f1': 1.0,
#  'loss': 0.3133070766925812,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00277: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00328: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00460: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00557: reducing learning rate of group 0 to 1.0000e-04.
# 114 Trace
# {'accuracy': 1.0,
#  'duration': 135.20783114433289,
#  'f1': 1.0,
#  'loss': 0.7439867854118347,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00118: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00169: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00271: reducing learning rate of group 0 to 1.0000e-04.
# 116 TwoPatterns
# {'accuracy': 1.0,
#  'duration': 3110.870280265808,
#  'f1': 1.0,
#  'loss': 0.743668932467699,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00137: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00324: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00485: reducing learning rate of group 0 to 1.0000e-04.
# 118 UWaveGestureLibraryAll
# {'accuracy': 0.9977678571428571,
#  'duration': 3001.9557778835297,
#  'f1': 0.9978078294254764,
#  'loss': 1.2762325406074524,
#  'precision': 0.9978973113738738,
#  'recall': 0.9977477477477478}
# Epoch 00286: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00342: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00393: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00444: reducing learning rate of group 0 to 1.0000e-04.
# 120 UWaveGestureLibraryY
# {'accuracy': 0.9787946428571429,
#  'duration': 1767.8342690467834,
#  'f1': 0.9785486451633773,
#  'loss': 1.2949354818889074,
#  'precision': 0.9790073326338531,
#  'recall': 0.9782190563566844}
# Epoch 00194: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00245: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00296: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00347: reducing learning rate of group 0 to 1.0000e-04.
# 122 Wafer
# {'accuracy': 1.0,
#  'duration': 3731.3395581245422,
#  'f1': 1.0,
#  'loss': 0.3133062366396189,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00472: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00547: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00598: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00649: reducing learning rate of group 0 to 1.0000e-04.
# 124 WordSynonyms
# {'accuracy': 0.8801498127340824,
#  'duration': 429.3838596343994,
#  'f1': 0.6603264385006179,
#  'loss': 2.3849636554718017,
#  'precision': 0.6268576962295686,
#  'recall': 0.72}
# Epoch 00056: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00107: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00158: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.0000e-04.
# 126 WormsTwoClass
# {'accuracy': 1.0,
#  'duration': 252.0097427368164,
#  'f1': 1.0,
#  'loss': 0.31346579392751056,
#  'precision': 1.0,
#  'recall': 1.0}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
