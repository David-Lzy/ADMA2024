# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST3

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try4_c_Classfier

# %%
DEVICE = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=1)

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 0:
        continue
    trainer = Trainer(
        dataset=i_dataset,
        epoch=1000,
        model=model_class,
        device=DEVICE,
    )
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00268: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00458: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00578: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00881: reducing learning rate of group 0 to 1.0000e-04.
# 1 Adiac
# {'accuracy': 0.7564102564102564,
#  'duration': 802.3905301094055,
#  'f1': 0.6361183406243861,
#  'loss': 2.935546704701015,
#  'precision': 0.5828225387048916,
#  'recall': 0.7227367227367227}
# Epoch 00367: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00418: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00469: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00520: reducing learning rate of group 0 to 1.0000e-04.
# 3 AllGestureWiimoteY
# {'accuracy': 1.0,
#  'duration': 278.11029505729675,
#  'f1': 1.0,
#  'loss': 1.4612476348876953,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00087: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00138: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00189: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00240: reducing learning rate of group 0 to 1.0000e-04.
# 5 ArrowHead
# {'accuracy': 1.0,
#  'duration': 46.51728677749634,
#  'f1': 1.0,
#  'loss': 0.551512598991394,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00153: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00204: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00255: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00306: reducing learning rate of group 0 to 1.0000e-04.
# 7 Beef
# {'accuracy': 1.0,
#  'duration': 30.645071983337402,
#  'f1': 1.0,
#  'loss': 0.905049204826355,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00119: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00170: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00221: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00272: reducing learning rate of group 0 to 1.0000e-04.
# 9 BirdChicken
# {'accuracy': 1.0,
#  'duration': 29.86751365661621,
#  'f1': 1.0,
#  'loss': 0.3132932782173157,
#  'precision': 1.0,
#  'recall': 1.0}
# 11 Car
# {'accuracy': 1.0,
#  'duration': 51.087482929229736,
#  'f1': 1.0,
#  'loss': 0.7436911463737488,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00345: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00396: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00447: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00498: reducing learning rate of group 0 to 1.0000e-04.
# 13 ChlorineConcentration
# {'accuracy': 0.9892933618843683,
#  'duration': 1318.7216188907623,
#  'f1': 0.986695331728925,
#  'loss': 0.5613526552915573,
#  'precision': 0.9911995898838004,
#  'recall': 0.9824240087397982}
# Epoch 00383: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00443: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00494: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00545: reducing learning rate of group 0 to 1.0000e-04.
# 15 Coffee
# {'accuracy': 1.0,
#  'duration': 36.84994173049927,
#  'f1': 1.0,
#  'loss': 0.31327563524246216,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00222: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00329: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00380: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00431: reducing learning rate of group 0 to 1.0000e-04.
# 17 CricketX
# {'accuracy': 1.0,
#  'duration': 209.51012229919434,
#  'f1': 1.0,
#  'loss': 1.6201397691454207,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00181: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00236: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00287: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00432: reducing learning rate of group 0 to 1.0000e-04.
# 19 CricketZ
# {'accuracy': 0.9974358974358974,
#  'duration': 209.0908224582672,
#  'f1': 0.9975442397977609,
#  'loss': 1.6214473588126046,
#  'precision': 0.9974747474747474,
#  'recall': 0.9976851851851851}
# 21 DiatomSizeReduction
# {'accuracy': 1.0,
#  'duration': 67.11245679855347,
#  'f1': 1.0,
#  'loss': 0.7436937093734741,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00069: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00120: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00171: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00222: reducing learning rate of group 0 to 1.0000e-04.
# 23 DistalPhalanxOutlineCorrect
# {'accuracy': 0.9916666666666667,
#  'duration': 416.13951587677,
#  'f1': 0.9910372581180034,
#  'loss': 0.32107765674591066,
#  'precision': 0.992467551145148,
#  'recall': 0.9896682396682397}
# Epoch 00066: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00122: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00173: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00224: reducing learning rate of group 0 to 1.0000e-04.
# 25 DodgerLoopDay
# {'accuracy': 1.0,
#  'duration': 59.27022981643677,
#  'f1': 1.0,
#  'loss': 1.1668994426727295,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00057: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00108: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00159: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00210: reducing learning rate of group 0 to 1.0000e-04.
# 27 DodgerLoopWeekend
# {'accuracy': 1.0,
#  'duration': 48.3692307472229,
#  'f1': 1.0,
#  'loss': 0.31329864263534546,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00064: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00115: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00166: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00217: reducing learning rate of group 0 to 1.0000e-04.
# 29 ECG5000
# {'accuracy': 0.994,
#  'duration': 1512.5524656772614,
#  'f1': 0.9811764705882353,
#  'loss': 0.9107051864266396,
#  'precision': 0.9966666666666667,
#  'recall': 0.968421052631579}
# Epoch 00144: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00253: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00304: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00355: reducing learning rate of group 0 to 1.0000e-04.
# 31 EOGHorizontalSignal
# {'accuracy': 1.0,
#  'duration': 544.3040914535522,
#  'f1': 1.0,
#  'loss': 1.6199763019879658,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00063: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00165: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00216: reducing learning rate of group 0 to 1.0000e-04.
# 33 Earthquakes
# {'accuracy': 1.0,
#  'duration': 210.0717008113861,
#  'f1': 1.0,
#  'loss': 0.31395049889882404,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00264: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00408: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00459: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00510: reducing learning rate of group 0 to 1.0000e-04.
# 35 EthanolLevel
# {'accuracy': 1.0,
#  'duration': 1035.591910123825,
#  'f1': 1.0,
#  'loss': 0.744497038424015,
#  'precision': 1.0,
#  'recall': 1.0}
# 37 FaceFour
# {'accuracy': 1.0,
#  'duration': 40.84250569343567,
#  'f1': 1.0,
#  'loss': 0.7436794638633728,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00374: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00425: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00545: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00596: reducing learning rate of group 0 to 1.0000e-04.
# 39 FiftyWords
# {'accuracy': 0.5911111111111111,
#  'duration': 235.48403143882751,
#  'f1': 0.2263184915042746,
#  'loss': 3.375293880701065,
#  'precision': 0.19151870027631118,
#  'recall': 0.2963636363636364}
# Epoch 00107: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00158: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00209: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00260: reducing learning rate of group 0 to 1.0000e-04.
# 41 FordA
# {'accuracy': 0.9975006942515968,
#  'duration': 2032.4938151836395,
#  'f1': 0.9974991320771402,
#  'loss': 0.31573468342162014,
#  'precision': 0.9974922989548802,
#  'recall': 0.9975061193371053}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00118: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00169: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.0000e-04.
# 43 FreezerRegularTrain
# {'accuracy': 1.0,
#  'duration': 445.9766573905945,
#  'f1': 1.0,
#  'loss': 0.3133218189080556,
#  'precision': 1.0,
#  'recall': 1.0}
# 45 Fungi
# {'accuracy': 1.0,
#  'duration': 50.310097455978394,
#  'f1': 1.0,
#  'loss': 1.9815983772277832,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00223: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00274: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00325: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00376: reducing learning rate of group 0 to 1.0000e-04.
# 47 GestureMidAirD2
# {'accuracy': 0.9182692307692307,
#  'duration': 120.01726365089417,
#  'f1': 0.8897364073834662,
#  'loss': 2.4529144763946533,
#  'precision': 0.8728139381985536,
#  'recall': 0.9182692307692307}
# Epoch 00258: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00328: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00379: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00430: reducing learning rate of group 0 to 1.0000e-04.
# 49 GesturePebbleZ1
# {'accuracy': 1.0,
#  'duration': 111.76449346542358,
#  'f1': 1.0,
#  'loss': 1.0489604075749714,
#  'precision': 1.0,
#  'recall': 1.0}
# 51 GunPoint
# {'accuracy': 1.0,
#  'duration': 137.80926847457886,
#  'f1': 1.0,
#  'loss': 0.3132668435573578,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00132: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00256: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00307: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00403: reducing learning rate of group 0 to 1.0000e-04.
# 53 GunPointMaleVersusFemale
# {'accuracy': 1.0,
#  'duration': 311.2888882160187,
#  'f1': 1.0,
#  'loss': 0.3137030402819316,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00057: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00108: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00167: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00218: reducing learning rate of group 0 to 1.0000e-04.
# 55 Ham
# {'accuracy': 1.0,
#  'duration': 73.36582136154175,
#  'f1': 1.0,
#  'loss': 0.31333746016025543,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00324: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00375: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00426: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00477: reducing learning rate of group 0 to 1.0000e-04.
# 57 Haptics
# {'accuracy': 1.0,
#  'duration': 262.9644389152527,
#  'f1': 1.0,
#  'loss': 0.9052152832349142,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# 59 HouseTwenty
# {'accuracy': 1.0,
#  'duration': 145.35610222816467,
#  'f1': 1.0,
#  'loss': 0.31327298283576965,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00104: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00155: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00206: reducing learning rate of group 0 to 1.0000e-04.
# 61 InsectEPGRegularTrain
# {'accuracy': 1.0,
#  'duration': 92.35013031959534,
#  'f1': 1.0,
#  'loss': 0.5515486001968384,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00231: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00282: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00333: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00384: reducing learning rate of group 0 to 1.0000e-04.
# 63 InsectWingbeatSound
# {'accuracy': 0.9954545454545455,
#  'duration': 358.1295018196106,
#  'f1': 0.9954517027687758,
#  'loss': 1.5470179319381714,
#  'precision': 0.9956709956709957,
#  'recall': 0.9954545454545454}
# Epoch 00106: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00157: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00259: reducing learning rate of group 0 to 1.0000e-04.
# 65 LargeKitchenAppliances
# {'accuracy': 1.0,
#  'duration': 339.35786390304565,
#  'f1': 1.0,
#  'loss': 0.5514569779237112,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00269: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00327: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00378: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00429: reducing learning rate of group 0 to 1.0000e-04.
# 67 Lightning7
# {'accuracy': 1.0,
#  'duration': 65.9395911693573,
#  'f1': 1.0,
#  'loss': 1.1661586165428162,
#  'precision': 1.0,
#  'recall': 1.0}
# 69 Meat
# {'accuracy': 1.0,
#  'duration': 41.80890154838562,
#  'f1': 1.0,
#  'loss': 0.5514736175537109,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00129: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00180: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00231: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00282: reducing learning rate of group 0 to 1.0000e-04.
# 71 MelbournePedestrian
# {'accuracy': 0.9991624790619765,
#  'duration': 795.8184752464294,
#  'f1': 0.9991483810179564,
#  'loss': 1.461977858292429,
#  'precision': 0.9991735537190083,
#  'recall': 0.9991304347826088}
# Epoch 00078: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00129: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00180: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00231: reducing learning rate of group 0 to 1.0000e-04.
# 73 MiddlePhalanxOutlineCorrect
# {'accuracy': 0.9933333333333333,
#  'duration': 438.2088849544525,
#  'f1': 0.9926739926739927,
#  'loss': 0.31951812505722044,
#  'precision': 0.9948979591836735,
#  'recall': 0.9905660377358491}
# Epoch 00059: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00110: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00161: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.0000e-04.
# 75 MixedShapesRegularTrain
# {'accuracy': 1.0,
#  'duration': 1213.8435227870941,
#  'f1': 1.0,
#  'loss': 0.9048439338803291,
#  'precision': 1.0,
#  'recall': 1.0}
# 77 MoteStrain
# {'accuracy': 1.0,
#  'duration': 205.01670241355896,
#  'f1': 1.0,
#  'loss': 0.31326600909233093,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00613: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00759: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00831: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00882: reducing learning rate of group 0 to 1.0000e-04.
# 79 NonInvasiveFetalECGThorax2
# {'accuracy': 0.9377777777777778,
#  'duration': 1759.545904159546,
#  'f1': 0.9023204178767281,
#  'loss': 2.8378424397830306,
#  'precision': 0.8827655897086947,
#  'recall': 0.928042328042328}
# Epoch 00309: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00391: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00442: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00493: reducing learning rate of group 0 to 1.0000e-04.
# 81 OliveOil
# {'accuracy': 0.9666666666666667,
#  'duration': 36.06675720214844,
#  'f1': 0.9752941176470589,
#  'loss': 0.7777673602104187,
#  'precision': 0.9722222222222222,
#  'recall': 0.9807692307692308}
# Epoch 00122: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00221: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00272: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00323: reducing learning rate of group 0 to 1.0000e-04.
# 83 PhalangesOutlinesCorrect
# {'accuracy': 0.99,
#  'duration': 1303.7422096729279,
#  'f1': 0.9889452393560396,
#  'loss': 0.32307526983063795,
#  'precision': 0.9912304756054755,
#  'recall': 0.9867774613595357}
# Epoch 00250: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00301: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00352: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00403: reducing learning rate of group 0 to 1.0000e-04.
# 85 PickupGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 36.94650387763977,
#  'f1': 1.0,
#  'loss': 1.4614579677581787,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00679: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00730: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00841: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00892: reducing learning rate of group 0 to 1.0000e-04.
# 87 PigArtPressure
# {'accuracy': 1.0,
#  'duration': 306.81138277053833,
#  'f1': 1.0,
#  'loss': 2.983976125717163,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00222: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00273: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00324: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.0000e-04.
# 89 Plane
# {'accuracy': 1.0,
#  'duration': 242.94476985931396,
#  'f1': 1.0,
#  'loss': 1.1654840111732483,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00145: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00196: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00247: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00298: reducing learning rate of group 0 to 1.0000e-04.
# 91 ProximalPhalanxOutlineAgeGroup
# {'accuracy': 0.9175,
#  'duration': 311.35373425483704,
#  'f1': 0.9255430629938362,
#  'loss': 0.6314381957054138,
#  'precision': 0.9234188920311167,
#  'recall': 0.9316261276692931}
# Epoch 00077: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00258: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00309: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00360: reducing learning rate of group 0 to 1.0000e-04.
# 93 ProximalPhalanxTW
# {'accuracy': 0.8625,
#  'duration': 311.4307005405426,
#  'f1': 0.4519336543989369,
#  'loss': 1.1648117814745222,
#  'precision': 0.4170634920634921,
#  'recall': 0.4955973847938416}
# Epoch 00198: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00249: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00300: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00351: reducing learning rate of group 0 to 1.0000e-04.
# 95 Rock
# {'accuracy': 1.0,
#  'duration': 95.50805974006653,
#  'f1': 1.0,
#  'loss': 0.7439349889755249,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00104: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00155: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00206: reducing learning rate of group 0 to 1.0000e-04.
# 97 SemgHandGenderCh2
# {'accuracy': 1.0,
#  'duration': 671.7227807044983,
#  'f1': 1.0,
#  'loss': 0.3134985566139221,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00171: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00222: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00273: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00344: reducing learning rate of group 0 to 1.0000e-04.
# 99 SemgHandSubjectCh2
# {'accuracy': 0.9622222222222222,
#  'duration': 822.4818658828735,
#  'f1': 0.9622660438552126,
#  'loss': 0.9982208535075188,
#  'precision': 0.9635323904312904,
#  'recall': 0.9622222222222222}
# Epoch 00055: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00106: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00157: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00208: reducing learning rate of group 0 to 1.0000e-04.
# 101 ShapeletSim
# {'accuracy': 1.0,
#  'duration': 60.959482192993164,
#  'f1': 1.0,
#  'loss': 0.3132800757884979,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00096: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00165: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00238: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00289: reducing learning rate of group 0 to 1.0000e-04.
# 103 SmallKitchenAppliances
# {'accuracy': 0.9706666666666667,
#  'duration': 340.3271508216858,
#  'f1': 0.9706570628251301,
#  'loss': 0.5813913941383362,
#  'precision': 0.9711623931623933,
#  'recall': 0.9706666666666667}
# Epoch 00054: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00105: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00156: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00207: reducing learning rate of group 0 to 1.0000e-04.
# 105 SonyAIBORobotSurface1
# {'accuracy': 1.0,
#  'duration': 121.32379508018494,
#  'f1': 1.0,
#  'loss': 0.3133437931537628,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00089: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00161: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00263: reducing learning rate of group 0 to 1.0000e-04.
# 107 StarLightCurves
# {'accuracy': 0.991,
#  'duration': 3492.9517815113068,
#  'f1': 0.9872331058771736,
#  'loss': 0.5608312264084816,
#  'precision': 0.9948453608247423,
#  'recall': 0.9802631578947368}
# Epoch 00156: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00239: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00336: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00387: reducing learning rate of group 0 to 1.0000e-04.
# 109 SwedishLeaf
# {'accuracy': 1.0,
#  'duration': 1068.2923295497894,
#  'f1': 1.0,
#  'loss': 1.8165421187877655,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00234: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00503: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00625: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00676: reducing learning rate of group 0 to 1.0000e-04.
# 111 SyntheticControl
# {'accuracy': 1.0,
#  'duration': 255.7472894191742,
#  'f1': 1.0,
#  'loss': 1.0435959339141845,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00081: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00132: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00183: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00234: reducing learning rate of group 0 to 1.0000e-04.
# 113 ToeSegmentation2
# {'accuracy': 1.0,
#  'duration': 59.48537611961365,
#  'f1': 1.0,
#  'loss': 0.31329551339149475,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00082: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00133: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00184: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00235: reducing learning rate of group 0 to 1.0000e-04.
# 115 TwoLeadECG
# {'accuracy': 1.0,
#  'duration': 204.43664979934692,
#  'f1': 1.0,
#  'loss': 0.3132888972759247,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00063: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00114: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00165: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00216: reducing learning rate of group 0 to 1.0000e-04.
# 117 UMD
# {'accuracy': 1.0,
#  'duration': 122.84297490119934,
#  'f1': 1.0,
#  'loss': 0.5515493750572205,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00108: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00289: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00495: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00546: reducing learning rate of group 0 to 1.0000e-04.
# 119 UWaveGestureLibraryX
# {'accuracy': 0.9933035714285714,
#  'duration': 895.7623620033264,
#  'f1': 0.9934899643364559,
#  'loss': 1.2806591306413924,
#  'precision': 0.9934069969398727,
#  'recall': 0.9936586282058724}
# Epoch 00243: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00294: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00345: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00396: reducing learning rate of group 0 to 1.0000e-04.
# 121 UWaveGestureLibraryZ
# {'accuracy': 0.9933035714285714,
#  'duration': 895.9267075061798,
#  'f1': 0.9933541328521988,
#  'loss': 1.2806626388004847,
#  'precision': 0.9934209789703161,
#  'recall': 0.9933298393436036}
# Epoch 00128: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00179: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00230: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00281: reducing learning rate of group 0 to 1.0000e-04.
# 123 Wine
# {'accuracy': 0.9473684210526315,
#  'duration': 39.78184366226196,
#  'f1': 0.9473684210526316,
#  'loss': 0.3803003430366516,
#  'precision': 0.95,
#  'recall': 0.95}
# Epoch 00174: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00225: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00276: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00327: reducing learning rate of group 0 to 1.0000e-04.
# 125 Worms
# {'accuracy': 0.988950276243094,
#  'duration': 179.60380029678345,
#  'f1': 0.9849612109744561,
#  'loss': 0.9152211745580038,
#  'precision': 0.9808888888888889,
#  'recall': 0.9893684210526317}
# Epoch 00290: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00341: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00392: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00443: reducing learning rate of group 0 to 1.0000e-04.
# 127 Yoga
# {'accuracy': 0.9966666666666667,
#  'duration': 624.5014538764954,
#  'f1': 0.9966394461807305,
#  'loss': 0.3164232909679413,
#  'precision': 0.9969512195121951,
#  'recall': 0.9963503649635037}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
