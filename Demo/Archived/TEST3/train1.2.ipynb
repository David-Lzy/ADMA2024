# %%
import sys
import os
__file__ = %pwd
sys.path.append(os.path.dirname(os.path.dirname(__file__)))
from __init__ import *
print('pwd:', __file__)
logger.setLevel(logging.INFO)
# Out:
# HOME_LOC: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1
# pwd: /homes/David_Li/Mega/University_of_Adelaide/Works/Project/CorrelationV0.1/CODE/Demo/TEST3

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
part_DATASETs = UNIVARIATE_DATASET_NAMES
from CODE.Train.correlated_inception_time import *

model_class = try4_c_Classfier

# %%
for i, i_dataset in enumerate(part_DATASETs):
    if i % 2 == 1:
        continue
    trainer = Trainer(dataset=i_dataset, epoch=1000, model=model_class)
    try:
        trainer.train_and_evaluate(to_device=True, override=True)
        print(i, i_dataset)
        pprint(trainer.train_result)
    except AttributeError:
        pass
# Out:
# Epoch 00252: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00471: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00552: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00630: reducing learning rate of group 0 to 1.0000e-04.
# 0 ACSF1
# {'accuracy': 0.98,
#  'duration': 176.7918028831482,
#  'f1': 0.9803827751196174,
#  'loss': 1.4881627559661865,
#  'precision': 0.9833333333333334,
#  'recall': 0.9800000000000001}
# Epoch 00246: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00297: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00348: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00399: reducing learning rate of group 0 to 1.0000e-04.
# 2 AllGestureWiimoteX
# {'accuracy': 1.0,
#  'duration': 281.39385509490967,
#  'f1': 1.0,
#  'loss': 1.4612196445465089,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00249: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00300: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00418: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00671: reducing learning rate of group 0 to 1.0000e-04.
# 4 AllGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 280.47251081466675,
#  'f1': 1.0,
#  'loss': 1.4612245321273805,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00072: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00123: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00174: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.0000e-04.
# 6 BME
# {'accuracy': 1.0,
#  'duration': 104.5323715209961,
#  'f1': 1.0,
#  'loss': 0.5515260696411133,
#  'precision': 1.0,
#  'recall': 1.0}
# 8 BeetleFly
# {'accuracy': 1.0,
#  'duration': 30.9136323928833,
#  'f1': 1.0,
#  'loss': 0.3132673501968384,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00566: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00629: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00680: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00731: reducing learning rate of group 0 to 1.0000e-04.
# 10 CBF
# {'accuracy': 1.0,
#  'duration': 192.9642472267151,
#  'f1': 1.0,
#  'loss': 0.5514553189277649,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00154: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.0000e-04.
# 12 Chinatown
# {'accuracy': 1.0,
#  'duration': 69.10979008674622,
#  'f1': 1.0,
#  'loss': 0.31330737471580505,
#  'precision': 1.0,
#  'recall': 1.0}
# 14 CinCECGTorso
# {'accuracy': 1.0,
#  'duration': 750.5457179546356,
#  'f1': 1.0,
#  'loss': 0.7436832189559937,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00073: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00124: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00175: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00226: reducing learning rate of group 0 to 1.0000e-04.
# 16 Computers
# {'accuracy': 1.0,
#  'duration': 229.2160723209381,
#  'f1': 1.0,
#  'loss': 0.3132833316922188,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00205: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00256: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00377: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00428: reducing learning rate of group 0 to 1.0000e-04.
# 18 CricketY
# {'accuracy': 1.0,
#  'duration': 200.16360521316528,
#  'f1': 1.0,
#  'loss': 1.6206748485565186,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00072: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00123: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00174: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.0000e-04.
# 20 Crop
# {'accuracy': 0.9709722222222222,
#  'duration': 6545.07858133316,
#  'f1': 0.970922643977588,
#  'loss': 2.2759535861226308,
#  'precision': 0.9712745182080602,
#  'recall': 0.9709722222222222}
# Epoch 00070: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00121: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00172: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00286: reducing learning rate of group 0 to 1.0000e-04.
# 22 DistalPhalanxOutlineAgeGroup
# {'accuracy': 0.9725,
#  'duration': 292.4637327194214,
#  'f1': 0.97658396260338,
#  'loss': 0.5761326892035348,
#  'precision': 0.9773671096345514,
#  'recall': 0.9758158006496562}
# Epoch 00118: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00169: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00252: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00303: reducing learning rate of group 0 to 1.0000e-04.
# 24 DistalPhalanxTW
# {'accuracy': 0.9525,
#  'duration': 290.22636103630066,
#  'f1': 0.8010368886745876,
#  'loss': 1.0848149572099959,
#  'precision': 0.7778804918291988,
#  'recall': 0.8273809523809524}
# Epoch 00052: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00103: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00154: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.0000e-04.
# 26 DodgerLoopGame
# {'accuracy': 1.0,
#  'duration': 46.18332886695862,
#  'f1': 1.0,
#  'loss': 0.31331199407577515,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00109: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00160: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00211: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00262: reducing learning rate of group 0 to 1.0000e-04.
# 28 ECG200
# {'accuracy': 1.0,
#  'duration': 225.95477676391602,
#  'f1': 1.0,
#  'loss': 0.31330178678035736,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00326: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00406: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00457: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00508: reducing learning rate of group 0 to 1.0000e-04.
# 30 ECGFiveDays
# {'accuracy': 1.0,
#  'duration': 132.74827098846436,
#  'f1': 1.0,
#  'loss': 0.31327399611473083,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00127: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00267: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00318: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00369: reducing learning rate of group 0 to 1.0000e-04.
# 32 EOGVerticalSignal
# {'accuracy': 1.0,
#  'duration': 545.6181387901306,
#  'f1': 1.0,
#  'loss': 1.6190235018730164,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00076: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00127: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00178: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00229: reducing learning rate of group 0 to 1.0000e-04.
# 34 ElectricDevices
# {'accuracy': 0.9787138695944432,
#  'duration': 17706.83944129944,
#  'f1': 0.9750342413344055,
#  'loss': 1.1867742700236183,
#  'precision': 0.9753335174765765,
#  'recall': 0.9751749536807124}
# Epoch 00302: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00353: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00480: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00531: reducing learning rate of group 0 to 1.0000e-04.
# 36 FaceAll
# {'accuracy': 1.0,
#  'duration': 1289.507158279419,
#  'f1': 1.0,
#  'loss': 1.754826757642958,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00263: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00314: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00511: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00562: reducing learning rate of group 0 to 1.0000e-04.
# 38 FacesUCR
# {'accuracy': 1.0,
#  'duration': 684.5145597457886,
#  'f1': 1.0,
#  'loss': 1.7548834681510925,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00273: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00324: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00375: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00426: reducing learning rate of group 0 to 1.0000e-04.
# 40 Fish
# {'accuracy': 1.0,
#  'duration': 133.6411211490631,
#  'f1': 1.0,
#  'loss': 1.1654926538467407,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00146: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00197: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00248: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00299: reducing learning rate of group 0 to 1.0000e-04.
# 42 FordB
# {'accuracy': 0.9975247524752475,
#  'duration': 2525.6955223083496,
#  'f1': 0.9975233345344298,
#  'loss': 0.3157937971123478,
#  'precision': 0.9975436703532047,
#  'recall': 0.9975043591979076}
# Epoch 00100: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00151: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00202: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00253: reducing learning rate of group 0 to 1.0000e-04.
# 44 FreezerSmallTrain
# {'accuracy': 1.0,
#  'duration': 398.4398708343506,
#  'f1': 1.0,
#  'loss': 0.3133135139942169,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00181: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00233: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00284: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00335: reducing learning rate of group 0 to 1.0000e-04.
# 46 GestureMidAirD1
# {'accuracy': 0.9567307692307693,
#  'duration': 164.2453808784485,
#  'f1': 0.9404725992961288,
#  'loss': 2.364258885383606,
#  'precision': 0.9290598290598291,
#  'recall': 0.9567307692307693}
# Epoch 00318: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00369: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00420: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00471: reducing learning rate of group 0 to 1.0000e-04.
# 48 GestureMidAirD3
# {'accuracy': 0.9375,
#  'duration': 164.18087458610535,
#  'f1': 0.9207539493530206,
#  'loss': 2.391077220439911,
#  'precision': 0.9101107226107227,
#  'recall': 0.9375}
# Epoch 00212: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00263: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00314: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00365: reducing learning rate of group 0 to 1.0000e-04.
# 50 GesturePebbleZ2
# {'accuracy': 1.0,
#  'duration': 131.49587559700012,
#  'f1': 1.0,
#  'loss': 1.0437910954157512,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00123: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00174: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00225: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00342: reducing learning rate of group 0 to 1.0000e-04.
# 52 GunPointAgeSpan
# {'accuracy': 1.0,
#  'duration': 334.04140615463257,
#  'f1': 1.0,
#  'loss': 0.3183221717675527,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00162: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00236: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00287: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00338: reducing learning rate of group 0 to 1.0000e-04.
# 54 GunPointOldVersusYoung
# {'accuracy': 1.0,
#  'duration': 333.88073110580444,
#  'f1': 1.0,
#  'loss': 0.31331513325373334,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00220: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00271: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00322: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00373: reducing learning rate of group 0 to 1.0000e-04.
# 56 HandOutlines
# {'accuracy': 0.987,
#  'duration': 2556.089975118637,
#  'f1': 0.9858330854123281,
#  'loss': 0.3277335837483406,
#  'precision': 0.9893305062796589,
#  'recall': 0.9826417153050797}
# Epoch 00096: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00147: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00198: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00249: reducing learning rate of group 0 to 1.0000e-04.
# 58 Herring
# {'accuracy': 1.0,
#  'duration': 56.39028549194336,
#  'f1': 1.0,
#  'loss': 0.3133433759212494,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00250: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00495: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00546: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00597: reducing learning rate of group 0 to 1.0000e-04.
# 60 InlineSkate
# {'accuracy': 0.98,
#  'duration': 471.7201988697052,
#  'f1': 0.9779022720199191,
#  'loss': 1.1809324622154236,
#  'precision': 0.9841269841269842,
#  'recall': 0.973922902494331}
# Epoch 00062: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00113: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00164: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00215: reducing learning rate of group 0 to 1.0000e-04.
# 62 InsectEPGSmallTrain
# {'accuracy': 1.0,
#  'duration': 93.06335616111755,
#  'f1': 1.0,
#  'loss': 0.551569938659668,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00150: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00201: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00252: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00303: reducing learning rate of group 0 to 1.0000e-04.
# 64 ItalyPowerDemand
# {'accuracy': 1.0,
#  'duration': 219.45237159729004,
#  'f1': 1.0,
#  'loss': 0.31430694460868835,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00086: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00137: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00188: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00239: reducing learning rate of group 0 to 1.0000e-04.
# 66 Lightning2
# {'accuracy': 1.0,
#  'duration': 57.72286629676819,
#  'f1': 1.0,
#  'loss': 0.3133484125137329,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00290: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00341: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00392: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00443: reducing learning rate of group 0 to 1.0000e-04.
# 68 Mallat
# {'accuracy': 1.0,
#  'duration': 783.2818193435669,
#  'f1': 1.0,
#  'loss': 1.2742964029312134,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00195: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00246: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00297: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00348: reducing learning rate of group 0 to 1.0000e-04.
# 70 MedicalImages
# {'accuracy': 0.9816272965879265,
#  'duration': 850.5840063095093,
#  'f1': 0.9878800646976472,
#  'loss': 1.4793408910433452,
#  'precision': 0.9966666666666667,
#  'recall': 0.9802898550724638}
# Epoch 00067: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00118: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00169: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00220: reducing learning rate of group 0 to 1.0000e-04.
# 72 MiddlePhalanxOutlineAgeGroup
# {'accuracy': 0.98,
#  'duration': 339.85160756111145,
#  'f1': 0.9780930932140074,
#  'loss': 0.5698738949639457,
#  'precision': 0.9806457431457432,
#  'recall': 0.9756943556521617}
# Epoch 00085: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00136: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00187: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00238: reducing learning rate of group 0 to 1.0000e-04.
# 74 MiddlePhalanxTW
# {'accuracy': 0.9473684210526315,
#  'duration': 339.5659282207489,
#  'f1': 0.8983967453349289,
#  'loss': 1.0917253664561681,
#  'precision': 0.96032741205155,
#  'recall': 0.8717054263565891}
# Epoch 00129: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00180: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00231: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00282: reducing learning rate of group 0 to 1.0000e-04.
# 76 MixedShapesSmallTrain
# {'accuracy': 1.0,
#  'duration': 854.8940842151642,
#  'f1': 1.0,
#  'loss': 0.9050195813179016,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00432: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00514: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00565: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00616: reducing learning rate of group 0 to 1.0000e-04.
# 78 NonInvasiveFetalECGThorax1
# {'accuracy': 0.9172222222222223,
#  'duration': 1794.162303686142,
#  'f1': 0.8712392736662777,
#  'loss': 2.8582734732792296,
#  'precision': 0.8477806792696886,
#  'recall': 0.9047619047619048}
# Epoch 00280: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00331: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00469: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00520: reducing learning rate of group 0 to 1.0000e-04.
# 80 OSULeaf
# {'accuracy': 1.0,
#  'duration': 178.07382917404175,
#  'f1': 1.0,
#  'loss': 1.0441966652870178,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00180: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00325: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00418: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00564: reducing learning rate of group 0 to 1.0000e-04.
# 82 PLAID
# {'accuracy': 0.7113594040968343,
#  'duration': 838.7918050289154,
#  'f1': 0.49643197973062153,
#  'loss': 1.837134771876865,
#  'precision': 0.48096062797436195,
#  'recall': 0.5382618522014316}
# Epoch 00137: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00210: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00266: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00317: reducing learning rate of group 0 to 1.0000e-04.
# 84 Phoneme
# {'accuracy': 0.8878504672897196,
#  'duration': 797.3955512046814,
#  'f1': 0.6182584120253803,
#  'loss': 2.8092933893203735,
#  'precision': 0.5897912419405633,
#  'recall': 0.6601577909270216}
# Epoch 00392: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00443: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00494: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00545: reducing learning rate of group 0 to 1.0000e-04.
# 86 PigAirwayPressure
# {'accuracy': 0.75,
#  'duration': 302.65009927749634,
#  'f1': 0.6655677655677655,
#  'loss': 3.2400048971176147,
#  'precision': 0.6211538461538461,
#  'recall': 0.75}
# Epoch 00435: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00689: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00740: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00791: reducing learning rate of group 0 to 1.0000e-04.
# 88 PigCVP
# {'accuracy': 0.9615384615384616,
#  'duration': 302.844624042511,
#  'f1': 0.9474358974358974,
#  'loss': 3.0250617265701294,
#  'precision': 0.9391025641025641,
#  'recall': 0.9615384615384616}
# Epoch 00165: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00216: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00267: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00318: reducing learning rate of group 0 to 1.0000e-04.
# 90 PowerCons
# {'accuracy': 1.0,
#  'duration': 396.7579548358917,
#  'f1': 1.0,
#  'loss': 0.3132691780726115,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00094: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00145: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00196: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00247: reducing learning rate of group 0 to 1.0000e-04.
# 92 ProximalPhalanxOutlineCorrect
# {'accuracy': 0.9866666666666667,
#  'duration': 498.78097343444824,
#  'f1': 0.9846388202613962,
#  'loss': 0.32618177831172945,
#  'precision': 0.9888452799008469,
#  'recall': 0.9807272357930019}
# Epoch 00103: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00154: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00205: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00256: reducing learning rate of group 0 to 1.0000e-04.
# 94 RefrigerationDevices
# {'accuracy': 0.9866666666666667,
#  'duration': 339.87714099884033,
#  'f1': 0.9866655145007548,
#  'loss': 0.564946194489797,
#  'precision': 0.9868541666666667,
#  'recall': 0.9866666666666667}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00104: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00155: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00206: reducing learning rate of group 0 to 1.0000e-04.
# 96 ScreenType
# {'accuracy': 1.0,
#  'duration': 339.25337076187134,
#  'f1': 1.0,
#  'loss': 0.5519477228323618,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00099: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00199: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00250: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00301: reducing learning rate of group 0 to 1.0000e-04.
# 98 SemgHandMovementCh2
# {'accuracy': 0.7555555555555555,
#  'duration': 829.7644486427307,
#  'f1': 0.7311612155665007,
#  'loss': 1.2991361916065216,
#  'precision': 0.781533375398504,
#  'recall': 0.7555555555555555}
# Epoch 00154: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00205: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00256: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00307: reducing learning rate of group 0 to 1.0000e-04.
# 100 ShakeGestureWiimoteZ
# {'accuracy': 1.0,
#  'duration': 56.506054162979126,
#  'f1': 1.0,
#  'loss': 1.461478590965271,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00323: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00374: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00629: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00680: reducing learning rate of group 0 to 1.0000e-04.
# 102 ShapesAll
# {'accuracy': 0.995,
#  'duration': 466.50847601890564,
#  'f1': 0.9949874686716792,
#  'loss': 3.1272925615310667,
#  'precision': 0.9954545454545455,
#  'recall': 0.995}
# Epoch 00110: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00161: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00263: reducing learning rate of group 0 to 1.0000e-04.
# 104 SmoothSubspace
# {'accuracy': 1.0,
#  'duration': 138.50658178329468,
#  'f1': 1.0,
#  'loss': 0.5514528751373291,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00561: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00643: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00694: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00745: reducing learning rate of group 0 to 1.0000e-04.
# 106 SonyAIBORobotSurface2
# {'accuracy': 1.0,
#  'duration': 187.15096521377563,
#  'f1': 1.0,
#  'loss': 0.3132683336734772,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00200: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00323: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00374: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00425: reducing learning rate of group 0 to 1.0000e-04.
# 108 Strawberry
# {'accuracy': 0.9951060358890701,
#  'duration': 425.70797514915466,
#  'f1': 0.9946553903831902,
#  'loss': 0.3181097835302353,
#  'precision': 0.9962216624685138,
#  'recall': 0.9931506849315068}
# 110 Symbols
# {'accuracy': 1.0,
#  'duration': 201.97748637199402,
#  'f1': 1.0,
#  'loss': 1.0436205863952637,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00053: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00104: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00155: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00206: reducing learning rate of group 0 to 1.0000e-04.
# 112 ToeSegmentation1
# {'accuracy': 1.0,
#  'duration': 84.75211691856384,
#  'f1': 1.0,
#  'loss': 0.3132898509502411,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00320: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00418: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00502: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00553: reducing learning rate of group 0 to 1.0000e-04.
# 114 Trace
# {'accuracy': 1.0,
#  'duration': 98.93222784996033,
#  'f1': 1.0,
#  'loss': 0.7436940968036652,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00110: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00161: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00212: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00263: reducing learning rate of group 0 to 1.0000e-04.
# 116 TwoPatterns
# {'accuracy': 1.0,
#  'duration': 2574.781759738922,
#  'f1': 1.0,
#  'loss': 0.7436683177947998,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00228: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00291: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00342: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00393: reducing learning rate of group 0 to 1.0000e-04.
# 118 UWaveGestureLibraryAll
# {'accuracy': 1.0,
#  'duration': 1824.4409053325653,
#  'f1': 1.0,
#  'loss': 1.2740190880639213,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00148: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00207: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00258: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00345: reducing learning rate of group 0 to 1.0000e-04.
# 120 UWaveGestureLibraryY
# {'accuracy': 0.9933035714285714,
#  'duration': 1079.4953935146332,
#  'f1': 0.9934927844753394,
#  'loss': 1.2807141031537737,
#  'precision': 0.9940508745156971,
#  'recall': 0.993088474025974}
# Epoch 00127: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00192: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00243: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00294: reducing learning rate of group 0 to 1.0000e-04.
# 122 Wafer
# {'accuracy': 1.0,
#  'duration': 2917.720572948456,
#  'f1': 1.0,
#  'loss': 0.31326198764145374,
#  'precision': 1.0,
#  'recall': 1.0}
# Epoch 00469: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00539: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00648: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00743: reducing learning rate of group 0 to 1.0000e-04.
# 124 WordSynonyms
# {'accuracy': 0.9588014981273408,
#  'duration': 282.8761496543884,
#  'f1': 0.8499275025877897,
#  'loss': 2.334360933303833,
#  'precision': 0.8404937884446082,
#  'recall': 0.8666666666666666}
# Epoch 00058: reducing learning rate of group 0 to 5.0000e-04.
# Epoch 00109: reducing learning rate of group 0 to 2.5000e-04.
# Epoch 00160: reducing learning rate of group 0 to 1.2500e-04.
# Epoch 00211: reducing learning rate of group 0 to 1.0000e-04.
# 126 WormsTwoClass
# {'accuracy': 0.988950276243094,
#  'duration': 178.5513355731964,
#  'f1': 0.9886163522012579,
#  'loss': 0.32380199432373047,
#  'precision': 0.9906542056074766,
#  'recall': 0.986842105263158}

# %%
keys = []
for k in sys.modules.keys():
    if "CODE.Attack.mix" in k:
        print(k)
        keys.append(k)
for k in keys:
    del sys.modules[k]

from CODE.Attack.mix import Mix

attack_model = Mix

# %%
# for i, i_dataset in enumerate(part_DATASETs):
#     attacker = attack_model(
#         train_method_path=trainer.method_path,
#         dataset=i_dataset,
#         model=model_class,
#     )

#     attacker.perturb_all(
#         to_device=True,
#         override=True,
#     )
#     print(i, i_dataset)
#     pprint(attacker.data)
#     print("\n")
